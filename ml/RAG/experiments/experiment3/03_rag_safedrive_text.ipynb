# %% [markdown]
# # 🎓 SafeDrive AI: RAG Multimodal & Edge AI (Notebook Final TFG)
#
# **Objetivo:** Arquitectura definitiva del sistema RAG local para el asistente post-accidente.
# Implementa Clean Code, ingesta multimodal con control de cuota (Gemini API), chunking optimizado para textos jurídico-médicos, y visualizaciones semánticas.
#
# ## 🗺️ Flujo del Sistema
# 1. Instalación de dependencias
# 2. Importaciones centralizadas (Clean Code)
# 3. Configuración Global (Hiperparámetros)
# 4. Ingesta Multimodal Segura (Gemini Vision + Rate Limiting)
# 5. Chunking de Alta Densidad Semántica
# 6. Indexación en ChromaDB (Local)
# 7. Pipeline RAG Edge (Inferencia Local)
# 8. Pruebas de Estrés
# 9. Visualización 2D (PCA Local)
# 10. Exportación a TensorFlow Embedding Projector

# %% [markdown]
# ## 🔧 Paso 1: Instalación de dependencias

# %%
# !pip install langchain langchain-chroma langchain-ollama chromadb pypdfium2 google-genai pillow scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\littledragon\appdata\roaming\python\python313\site-packages (1.3.1)
# Requirement already satisfied: langchain-chroma in c:\users\littledragon\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: langchain-ollama in c:\users\littledragon\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: chromadb in c:\users\littledragon\appdata\roaming\python\python313\site-packages (1.5.9)
# Requirement already satisfied: pypdfium2 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (5.8.0)
# Requirement already satisfied: google-genai in c:\users\littledragon\appdata\roaming\python\python313\site-packages (2.3.0)
# Requirement already satisfied: pillow in c:\users\littledragon\appdata\roaming\python\python313\site-packages (12.2.0)
# Requirement already satisfied: scikit-learn in c:\users\littledragon\appdata\roaming\python\python313\site-packages (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\littledragon\appdata\roaming\python\python313\site-packages (3.10.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain) (1.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.15)
# Requirement already satisfied: h11>=0.16 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-chroma) (2.3.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.47.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from langchain-ollama) (0.6.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.53.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from google-genai) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (48.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.7.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyproject_hooks in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from tokenizers>=0.13.2->chromadb) (1.15.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\littledragon\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 📦 Paso 2: Importaciones Centralizadas (Clean Code)
# Agrupamos todas las librerías en la primera celda ejecutable para evitar errores de dependencias en el flujo.

# %%
# 1. Librerías del Sistema y Datos
import os
import csv
import time
from pathlib import Path
from tqdm import tqdm

# 2. Librerías de Procesamiento de Imágenes y PDFs
from PIL import Image
import pypdfium2 as pdfium

# 3. Librería del Modelo de Visión 
import base64
from io import BytesIO
from langchain_core.messages import HumanMessage
from langchain_core.prompts import PromptTemplate

# 4. Librerías de LangChain y Arquitectura RAG
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings, OllamaLLM, ChatOllama
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# 5. Librerías para Análisis Matemático y Visualización (PCA)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

print("✅ Todas las librerías importadas correctamente. Entorno listo.")
# Out:
# ✅ Todas las librerías importadas correctamente. Entorno listo.

# %% [markdown]
# ## ⚙️ Paso 3: Configuración Global (Hiperparámetros y Rutas)
# Definición estricta de parámetros. Hemos ajustado el `CHUNK_SIZE` a 512 y el `CHUNK_OVERLAP` a 150 para maximizar la cohesión de los artículos legales y evitar fragmentación semántica.

# %%
# --- RUTAS DE DIRECTORIOS ---
DATA_DIR = "../data/" 
CHROMA_DIR = "../chroma_db/dgt_multimodal"
COLLECTION_NAME = "BOE_dgt_seguridad"

# --- CONFIGURACIÓN DE MODELOS ---
OLLAMA_BASE_URL = "http://localhost:11434"
EMBEDDING_MODEL = "nomic-embed-text"
LLM_MODEL = "qwen2.5:7b"
OLLAMA_VISION_MODEL = "qwen2.5vl"

# --- CONFIGURACIÓN RAG (Densidad Semántica) ---
CHUNK_SIZE = 512
CHUNK_OVERLAP = 150

print(f"✅ Configuración global cargada: Chunk={CHUNK_SIZE}, Overlap={CHUNK_OVERLAP}")
# Out:
# ✅ Configuración global cargada: Chunk=512, Overlap=150

# %% [markdown]
# ## 📂 Paso 4: Ingesta Multimodal Segura (ETL)
# Extrae texto y envía imágenes a Gemini para análisis técnico. Uso del modelo de visión local de Alibaba (Qwen2.5-VL)

# %%
def procesar_pdf_solo_texto(ruta_pdf: str) -> list:
    print(f"\n📄 Procesando PDF (Modo Texto Rápido): {Path(ruta_pdf).name}")
    documentos_generados = []
    pdf = pdfium.PdfDocument(ruta_pdf)
    
    for page_idx in range(len(pdf)):
        pagina = pdf[page_idx]
        
        # 1. Extraemos el texto nativo digital (Coste cero de VRAM)
        texto_nativo = pagina.get_textpage().get_text_bounded() or ""
        
        # Log informativo para saber si la página traía texto o venía vacía/gráfica
        if texto_nativo.strip():
            print(f"   🔤 [Pág {page_idx + 1}] Texto extraído correctamente.")
        else:
            print(f"   ⚠️ [Pág {page_idx + 1}] Página sin texto digital (posiblemente un anexo gráfico o plano).")
        
        # 2. Consolidamos el documento directamente para tu ChromaDB
        contenido_final = f"--- TEXTO DE LA PÁGINA ---\n{texto_nativo}\n"

        doc = Document(
            page_content=contenido_final,
            metadata={
                "source": Path(ruta_pdf).name, 
                "pagina": page_idx + 1
            }
        )
        documentos_generados.append(doc)
        
    return documentos_generados

# =====================================================================
# EJECUCIÓN DEL PIPELINE DE TEXTO PLANO
# =====================================================================
os.makedirs(DATA_DIR, exist_ok=True)
docs_totales = []

# Forzamos el orden alfabético estricto de tu carpeta de datos
archivos_pdf = sorted([f for f in os.listdir(DATA_DIR) if f.lower().endswith(".pdf")])

for archivo in archivos_pdf:
    ruta_completa = os.path.join(DATA_DIR, archivo)
    docs_totales.extend(procesar_pdf_solo_texto(ruta_completa))
    
print(f"\n✅ Carga Rápida completada. Total páginas listas para ChromaDB: {len(docs_totales)}")
# Out:
# 📄 Procesando PDF (Modo Texto Rápido): BOE-A-1995-25444-consolidado.pdf
#    🔤 [Pág 1] Texto extraído correctamente.
#    🔤 [Pág 2] Texto extraído correctamente.
#    🔤 [Pág 3] Texto extraído correctamente.
#    🔤 [Pág 4] Texto extraído correctamente.
#    🔤 [Pág 5] Texto extraído correctamente.
#    🔤 [Pág 6] Texto extraído correctamente.
#    🔤 [Pág 7] Texto extraído correctamente.
#    🔤 [Pág 8] Texto extraído correctamente.
#    🔤 [Pág 9] Texto extraído correctamente.
#    🔤 [Pág 10] Texto extraído correctamente.
#    🔤 [Pág 11] Texto extraído correctamente.
#    🔤 [Pág 12] Texto extraído correctamente.
#    🔤 [Pág 13] Texto extraído correctamente.
#    🔤 [Pág 14] Texto extraído correctamente.
#    🔤 [Pág 15] Texto extraído correctamente.
#    🔤 [Pág 16] Texto extraído correctamente.
#    🔤 [Pág 17] Texto extraído correctamente.
#    🔤 [Pág 18] Texto extraído correctamente.
#    🔤 [Pág 19] Texto extraído correctamente.
#    🔤 [Pág 20] Texto extraído correctamente.
#    🔤 [Pág 21] Texto extraído correctamente.
#    🔤 [Pág 22] Texto extraído correctamente.
#    🔤 [Pág 23] Texto extraído correctamente.
#    🔤 [Pág 24] Texto extraído correctamente.
#    🔤 [Pág 25] Texto extraído correctamente.
#    🔤 [Pág 26] Texto extraído correctamente.
#    🔤 [Pág 27] Texto extraído correctamente.
#    🔤 [Pág 28] Texto extraído correctamente.
#    🔤 [Pág 29] Texto extraído correctamente.
#    🔤 [Pág 30] Texto extraído correctamente.
#    🔤 [Pág 31] Texto extraído correctamente.
#    🔤 [Pág 32] Texto extraído correctamente.
#    🔤 [Pág 33] Texto extraído correctamente.
#    🔤 [Pág 34] Texto extraído correctamente.
#    🔤 [Pág 35] Texto extraído correctamente.
#    🔤 [Pág 36] Texto extraído correctamente.
#    🔤 [Pág 37] Texto extraído correctamente.
#    🔤 [Pág 38] Texto extraído correctamente.
#    🔤 [Pág 39] Texto extraído correctamente.
#    🔤 [Pág 40] Texto extraído correctamente.
#    🔤 [Pág 41] Texto extraído correctamente.
#    🔤 [Pág 42] Texto extraído correctamente.
#    🔤 [Pág 43] Texto extraído correctamente.
#    🔤 [Pág 44] Texto extraído correctamente.
#    🔤 [Pág 45] Texto extraído correctamente.
#    🔤 [Pág 46] Texto extraído correctamente.
#    🔤 [Pág 47] Texto extraído correctamente.
#    🔤 [Pág 48] Texto extraído correctamente.
#    🔤 [Pág 49] Texto extraído correctamente.
#    🔤 [Pág 50] Texto extraído correctamente.
#    🔤 [Pág 51] Texto extraído correctamente.
#    🔤 [Pág 52] Texto extraído correctamente.
#    🔤 [Pág 53] Texto extraído correctamente.
#    🔤 [Pág 54] Texto extraído correctamente.
#    🔤 [Pág 55] Texto extraído correctamente.
#    🔤 [Pág 56] Texto extraído correctamente.
#    🔤 [Pág 57] Texto extraído correctamente.
#    🔤 [Pág 58] Texto extraído correctamente.
#    🔤 [Pág 59] Texto extraído correctamente.
#    🔤 [Pág 60] Texto extraído correctamente.
#    🔤 [Pág 61] Texto extraído correctamente.
#    🔤 [Pág 62] Texto extraído correctamente.
#    🔤 [Pág 63] Texto extraído correctamente.
#    🔤 [Pág 64] Texto extraído correctamente.
#    🔤 [Pág 65] Texto extraído correctamente.
#    🔤 [Pág 66] Texto extraído correctamente.
#    🔤 [Pág 67] Texto extraído correctamente.
#    🔤 [Pág 68] Texto extraído correctamente.
#    🔤 [Pág 69] Texto extraído correctamente.
#    🔤 [Pág 70] Texto extraído correctamente.
#    🔤 [Pág 71] Texto extraído correctamente.
#    🔤 [Pág 72] Texto extraído correctamente.
#    🔤 [Pág 73] Texto extraído correctamente.
#    🔤 [Pág 74] Texto extraído correctamente.
#    🔤 [Pág 75] Texto extraído correctamente.
#    🔤 [Pág 76] Texto extraído correctamente.
#    🔤 [Pág 77] Texto extraído correctamente.
#    🔤 [Pág 78] Texto extraído correctamente.
#    🔤 [Pág 79] Texto extraído correctamente.
#    🔤 [Pág 80] Texto extraído correctamente.
#    🔤 [Pág 81] Texto extraído correctamente.
#    🔤 [Pág 82] Texto extraído correctamente.
#    🔤 [Pág 83] Texto extraído correctamente.
#    🔤 [Pág 84] Texto extraído correctamente.
#    🔤 [Pág 85] Texto extraído correctamente.
#    🔤 [Pág 86] Texto extraído correctamente.
#    🔤 [Pág 87] Texto extraído correctamente.
#    🔤 [Pág 88] Texto extraído correctamente.
#    🔤 [Pág 89] Texto extraído correctamente.
#    🔤 [Pág 90] Texto extraído correctamente.
#    🔤 [Pág 91] Texto extraído correctamente.
#    🔤 [Pág 92] Texto extraído correctamente.
#    🔤 [Pág 93] Texto extraído correctamente.
#    🔤 [Pág 94] Texto extraído correctamente.
#    🔤 [Pág 95] Texto extraído correctamente.
#    🔤 [Pág 96] Texto extraído correctamente.
#    🔤 [Pág 97] Texto extraído correctamente.
#    🔤 [Pág 98] Texto extraído correctamente.
#    🔤 [Pág 99] Texto extraído correctamente.
#    🔤 [Pág 100] Texto extraído correctamente.
#    🔤 [Pág 101] Texto extraído correctamente.
#    🔤 [Pág 102] Texto extraído correctamente.
#    🔤 [Pág 103] Texto extraído correctamente.
#    🔤 [Pág 104] Texto extraído correctamente.
#    🔤 [Pág 105] Texto extraído correctamente.
#    🔤 [Pág 106] Texto extraído correctamente.
#    🔤 [Pág 107] Texto extraído correctamente.
#    🔤 [Pág 108] Texto extraído correctamente.
#    🔤 [Pág 109] Texto extraído correctamente.
#    🔤 [Pág 110] Texto extraído correctamente.
#    🔤 [Pág 111] Texto extraído correctamente.
#    🔤 [Pág 112] Texto extraído correctamente.
#    🔤 [Pág 113] Texto extraído correctamente.
#    🔤 [Pág 114] Texto extraído correctamente.
#    🔤 [Pág 115] Texto extraído correctamente.
#    🔤 [Pág 116] Texto extraído correctamente.
#    🔤 [Pág 117] Texto extraído correctamente.
#    🔤 [Pág 118] Texto extraído correctamente.
#    🔤 [Pág 119] Texto extraído correctamente.
#    🔤 [Pág 120] Texto extraído correctamente.
#    🔤 [Pág 121] Texto extraído correctamente.
#    🔤 [Pág 122] Texto extraído correctamente.
#    🔤 [Pág 123] Texto extraído correctamente.
#    🔤 [Pág 124] Texto extraído correctamente.
#    🔤 [Pág 125] Texto extraído correctamente.
#    🔤 [Pág 126] Texto extraído correctamente.
#    🔤 [Pág 127] Texto extraído correctamente.
#    🔤 [Pág 128] Texto extraído correctamente.
#    🔤 [Pág 129] Texto extraído correctamente.
#    🔤 [Pág 130] Texto extraído correctamente.
#    🔤 [Pág 131] Texto extraído correctamente.
#    🔤 [Pág 132] Texto extraído correctamente.
#    🔤 [Pág 133] Texto extraído correctamente.
#    🔤 [Pág 134] Texto extraído correctamente.
#    🔤 [Pág 135] Texto extraído correctamente.
#    🔤 [Pág 136] Texto extraído correctamente.
#    🔤 [Pág 137] Texto extraído correctamente.
#    🔤 [Pág 138] Texto extraído correctamente.
#    🔤 [Pág 139] Texto extraído correctamente.
#    🔤 [Pág 140] Texto extraído correctamente.
#    🔤 [Pág 141] Texto extraído correctamente.
#    🔤 [Pág 142] Texto extraído correctamente.
#    🔤 [Pág 143] Texto extraído correctamente.
#    🔤 [Pág 144] Texto extraído correctamente.
#    🔤 [Pág 145] Texto extraído correctamente.
#    🔤 [Pág 146] Texto extraído correctamente.
#    🔤 [Pág 147] Texto extraído correctamente.
#    🔤 [Pág 148] Texto extraído correctamente.
#    🔤 [Pág 149] Texto extraído correctamente.
#    🔤 [Pág 150] Texto extraído correctamente.
#    🔤 [Pág 151] Texto extraído correctamente.
#    🔤 [Pág 152] Texto extraído correctamente.
#    🔤 [Pág 153] Texto extraído correctamente.
#    🔤 [Pág 154] Texto extraído correctamente.
#    🔤 [Pág 155] Texto extraído correctamente.
#    🔤 [Pág 156] Texto extraído correctamente.
#    🔤 [Pág 157] Texto extraído correctamente.
#    🔤 [Pág 158] Texto extraído correctamente.
#    🔤 [Pág 159] Texto extraído correctamente.
#    🔤 [Pág 160] Texto extraído correctamente.
#    🔤 [Pág 161] Texto extraído correctamente.
#    🔤 [Pág 162] Texto extraído correctamente.
#    🔤 [Pág 163] Texto extraído correctamente.
#    🔤 [Pág 164] Texto extraído correctamente.
#    🔤 [Pág 165] Texto extraído correctamente.
#    🔤 [Pág 166] Texto extraído correctamente.
#    🔤 [Pág 167] Texto extraído correctamente.
#    🔤 [Pág 168] Texto extraído correctamente.
#    🔤 [Pág 169] Texto extraído correctamente.
#    🔤 [Pág 170] Texto extraído correctamente.
#    🔤 [Pág 171] Texto extraído correctamente.
#    🔤 [Pág 172] Texto extraído correctamente.
#    🔤 [Pág 173] Texto extraído correctamente.
#    🔤 [Pág 174] Texto extraído correctamente.
#    🔤 [Pág 175] Texto extraído correctamente.
#    🔤 [Pág 176] Texto extraído correctamente.
#    🔤 [Pág 177] Texto extraído correctamente.
#    🔤 [Pág 178] Texto extraído correctamente.
#    🔤 [Pág 179] Texto extraído correctamente.
#    🔤 [Pág 180] Texto extraído correctamente.
#    🔤 [Pág 181] Texto extraído correctamente.
#    🔤 [Pág 182] Texto extraído correctamente.
#    🔤 [Pág 183] Texto extraído correctamente.
#    🔤 [Pág 184] Texto extraído correctamente.
#    🔤 [Pág 185] Texto extraído correctamente.
#    🔤 [Pág 186] Texto extraído correctamente.
#    🔤 [Pág 187] Texto extraído correctamente.
#    🔤 [Pág 188] Texto extraído correctamente.
#    🔤 [Pág 189] Texto extraído correctamente.
#    🔤 [Pág 190] Texto extraído correctamente.
#    🔤 [Pág 191] Texto extraído correctamente.
#    🔤 [Pág 192] Texto extraído correctamente.
#    🔤 [Pág 193] Texto extraído correctamente.
#    🔤 [Pág 194] Texto extraído correctamente.
#    🔤 [Pág 195] Texto extraído correctamente.
#    🔤 [Pág 196] Texto extraído correctamente.
#    🔤 [Pág 197] Texto extraído correctamente.
#    🔤 [Pág 198] Texto extraído correctamente.
#    🔤 [Pág 199] Texto extraído correctamente.
#    🔤 [Pág 200] Texto extraído correctamente.
#    🔤 [Pág 201] Texto extraído correctamente.
#    🔤 [Pág 202] Texto extraído correctamente.
#    🔤 [Pág 203] Texto extraído correctamente.
#    🔤 [Pág 204] Texto extraído correctamente.
#    🔤 [Pág 205] Texto extraído correctamente.
#    🔤 [Pág 206] Texto extraído correctamente.
#    🔤 [Pág 207] Texto extraído correctamente.
#
# 📄 Procesando PDF (Modo Texto Rápido): BOE-A-2003-23514-consolidado.pdf
#    🔤 [Pág 1] Texto extraído correctamente.
#    🔤 [Pág 2] Texto extraído correctamente.
#    🔤 [Pág 3] Texto extraído correctamente.
#    🔤 [Pág 4] Texto extraído correctamente.
#    🔤 [Pág 5] Texto extraído correctamente.
#    🔤 [Pág 6] Texto extraído correctamente.
#    🔤 [Pág 7] Texto extraído correctamente.
#    🔤 [Pág 8] Texto extraído correctamente.
#    🔤 [Pág 9] Texto extraído correctamente.
#    🔤 [Pág 10] Texto extraído correctamente.
#    🔤 [Pág 11] Texto extraído correctamente.
#    🔤 [Pág 12] Texto extraído correctamente.
#    🔤 [Pág 13] Texto extraído correctamente.
#    🔤 [Pág 14] Texto extraído correctamente.
#    🔤 [Pág 15] Texto extraído correctamente.
#    🔤 [Pág 16] Texto extraído correctamente.
#    🔤 [Pág 17] Texto extraído correctamente.
#    🔤 [Pág 18] Texto extraído correctamente.
#    🔤 [Pág 19] Texto extraído correctamente.
#    🔤 [Pág 20] Texto extraído correctamente.
#    🔤 [Pág 21] Texto extraído correctamente.
#    🔤 [Pág 22] Texto extraído correctamente.
#    🔤 [Pág 23] Texto extraído correctamente.
#    🔤 [Pág 24] Texto extraído correctamente.
#    🔤 [Pág 25] Texto extraído correctamente.
#    🔤 [Pág 26] Texto extraído correctamente.
#    🔤 [Pág 27] Texto extraído correctamente.
#    🔤 [Pág 28] Texto extraído correctamente.
#    🔤 [Pág 29] Texto extraído correctamente.
#    🔤 [Pág 30] Texto extraído correctamente.
#    🔤 [Pág 31] Texto extraído correctamente.
#    🔤 [Pág 32] Texto extraído correctamente.
#    🔤 [Pág 33] Texto extraído correctamente.
#    🔤 [Pág 34] Texto extraído correctamente.
#    🔤 [Pág 35] Texto extraído correctamente.
#    🔤 [Pág 36] Texto extraído correctamente.
#    🔤 [Pág 37] Texto extraído correctamente.
#    🔤 [Pág 38] Texto extraído correctamente.
#    🔤 [Pág 39] Texto extraído correctamente.
#    🔤 [Pág 40] Texto extraído correctamente.
#    🔤 [Pág 41] Texto extraído correctamente.
#    🔤 [Pág 42] Texto extraído correctamente.
#    🔤 [Pág 43] Texto extraído correctamente.
#    🔤 [Pág 44] Texto extraído correctamente.
#    🔤 [Pág 45] Texto extraído correctamente.
#    🔤 [Pág 46] Texto extraído correctamente.
#    🔤 [Pág 47] Texto extraído correctamente.
#    🔤 [Pág 48] Texto extraído correctamente.
#    🔤 [Pág 49] Texto extraído correctamente.
#    🔤 [Pág 50] Texto extraído correctamente.
#    🔤 [Pág 51] Texto extraído correctamente.
#    🔤 [Pág 52] Texto extraído correctamente.
#    🔤 [Pág 53] Texto extraído correctamente.
#    🔤 [Pág 54] Texto extraído correctamente.
#    🔤 [Pág 55] Texto extraído correctamente.
#    🔤 [Pág 56] Texto extraído correctamente.
#    🔤 [Pág 57] Texto extraído correctamente.
#    🔤 [Pág 58] Texto extraído correctamente.
#    🔤 [Pág 59] Texto extraído correctamente.
#    🔤 [Pág 60] Texto extraído correctamente.
#    🔤 [Pág 61] Texto extraído correctamente.
#    🔤 [Pág 62] Texto extraído correctamente.
#    🔤 [Pág 63] Texto extraído correctamente.
#    🔤 [Pág 64] Texto extraído correctamente.
#    🔤 [Pág 65] Texto extraído correctamente.
#    🔤 [Pág 66] Texto extraído correctamente.
#    🔤 [Pág 67] Texto extraído correctamente.
#    🔤 [Pág 68] Texto extraído correctamente.
#    🔤 [Pág 69] Texto extraído correctamente.
#    🔤 [Pág 70] Texto extraído correctamente.
#    🔤 [Pág 71] Texto extraído correctamente.
#    🔤 [Pág 72] Texto extraído correctamente.
#    🔤 [Pág 73] Texto extraído correctamente.
#    🔤 [Pág 74] Texto extraído correctamente.
#    🔤 [Pág 75] Texto extraído correctamente.
#    🔤 [Pág 76] Texto extraído correctamente.
#    🔤 [Pág 77] Texto extraído correctamente.
#    🔤 [Pág 78] Texto extraído correctamente.
#    🔤 [Pág 79] Texto extraído correctamente.
#    🔤 [Pág 80] Texto extraído correctamente.
#    🔤 [Pág 81] Texto extraído correctamente.
#    🔤 [Pág 82] Texto extraído correctamente.
#    🔤 [Pág 83] Texto extraído correctamente.
#    🔤 [Pág 84] Texto extraído correctamente.
#    🔤 [Pág 85] Texto extraído correctamente.
#    🔤 [Pág 86] Texto extraído correctamente.
#    🔤 [Pág 87] Texto extraído correctamente.
#    🔤 [Pág 88] Texto extraído correctamente.
#    🔤 [Pág 89] Texto extraído correctamente.
#    🔤 [Pág 90] Texto extraído correctamente.
#    🔤 [Pág 91] Texto extraído correctamente.
#    🔤 [Pág 92] Texto extraído correctamente.
#    🔤 [Pág 93] Texto extraído correctamente.
#    🔤 [Pág 94] Texto extraído correctamente.
#    🔤 [Pág 95] Texto extraído correctamente.
#    🔤 [Pág 96] Texto extraído correctamente.
#    🔤 [Pág 97] Texto extraído correctamente.
#    🔤 [Pág 98] Texto extraído correctamente.
#    🔤 [Pág 99] Texto extraído correctamente.
#    🔤 [Pág 100] Texto extraído correctamente.
#    🔤 [Pág 101] Texto extraído correctamente.
#    🔤 [Pág 102] Texto extraído correctamente.
#    🔤 [Pág 103] Texto extraído correctamente.
#    🔤 [Pág 104] Texto extraído correctamente.
#    🔤 [Pág 105] Texto extraído correctamente.
#    🔤 [Pág 106] Texto extraído correctamente.
#    🔤 [Pág 107] Texto extraído correctamente.
#    🔤 [Pág 108] Texto extraído correctamente.
#    🔤 [Pág 109] Texto extraído correctamente.
#    🔤 [Pág 110] Texto extraído correctamente.
#    🔤 [Pág 111] Texto extraído correctamente.
#    🔤 [Pág 112] Texto extraído correctamente.
#    🔤 [Pág 113] Texto extraído correctamente.
#    🔤 [Pág 114] Texto extraído correctamente.
#    🔤 [Pág 115] Texto extraído correctamente.
#    🔤 [Pág 116] Texto extraído correctamente.
#    🔤 [Pág 117] Texto extraído correctamente.
#    🔤 [Pág 118] Texto extraído correctamente.
#    🔤 [Pág 119] Texto extraído correctamente.
#    🔤 [Pág 120] Texto extraído correctamente.
#    🔤 [Pág 121] Texto extraído correctamente.
#    🔤 [Pág 122] Texto extraído correctamente.
#    🔤 [Pág 123] Texto extraído correctamente.
#    🔤 [Pág 124] Texto extraído correctamente.
#    🔤 [Pág 125] Texto extraído correctamente.
#    🔤 [Pág 126] Texto extraído correctamente.
#    🔤 [Pág 127] Texto extraído correctamente.
#    🔤 [Pág 128] Texto extraído correctamente.
#    🔤 [Pág 129] Texto extraído correctamente.
#    🔤 [Pág 130] Texto extraído correctamente.
#    🔤 [Pág 131] Texto extraído correctamente.
#    🔤 [Pág 132] Texto extraído correctamente.
#    🔤 [Pág 133] Texto extraído correctamente.
#    🔤 [Pág 134] Texto extraído correctamente.
#    🔤 [Pág 135] Texto extraído correctamente.
#    🔤 [Pág 136] Texto extraído correctamente.
#    🔤 [Pág 137] Texto extraído correctamente.
#    🔤 [Pág 138] Texto extraído correctamente.
#    🔤 [Pág 139] Texto extraído correctamente.
#    🔤 [Pág 140] Texto extraído correctamente.
#    🔤 [Pág 141] Texto extraído correctamente.
#    🔤 [Pág 142] Texto extraído correctamente.
#    🔤 [Pág 143] Texto extraído correctamente.
#    🔤 [Pág 144] Texto extraído correctamente.
#    🔤 [Pág 145] Texto extraído correctamente.
#    🔤 [Pág 146] Texto extraído correctamente.
#    🔤 [Pág 147] Texto extraído correctamente.
#    🔤 [Pág 148] Texto extraído correctamente.
#    🔤 [Pág 149] Texto extraído correctamente.
#    🔤 [Pág 150] Texto extraído correctamente.
#    🔤 [Pág 151] Texto extraído correctamente.
#    🔤 [Pág 152] Texto extraído correctamente.
#    🔤 [Pág 153] Texto extraído correctamente.
#    🔤 [Pág 154] Texto extraído correctamente.
#    🔤 [Pág 155] Texto extraído correctamente.
#    🔤 [Pág 156] Texto extraído correctamente.
#    🔤 [Pág 157] Texto extraído correctamente.
#    🔤 [Pág 158] Texto extraído correctamente.
#    🔤 [Pág 159] Texto extraído correctamente.
#    🔤 [Pág 160] Texto extraído correctamente.
#    🔤 [Pág 161] Texto extraído correctamente.
#    🔤 [Pág 162] Texto extraído correctamente.
#    🔤 [Pág 163] Texto extraído correctamente.
#    🔤 [Pág 164] Texto extraído correctamente.
#    🔤 [Pág 165] Texto extraído correctamente.
#    🔤 [Pág 166] Texto extraído correctamente.
#    🔤 [Pág 167] Texto extraído correctamente.
#    🔤 [Pág 168] Texto extraído correctamente.
#    🔤 [Pág 169] Texto extraído correctamente.
#    🔤 [Pág 170] Texto extraído correctamente.
#    🔤 [Pág 171] Texto extraído correctamente.
#    🔤 [Pág 172] Texto extraído correctamente.
#    🔤 [Pág 173] Texto extraído correctamente.
#    🔤 [Pág 174] Texto extraído correctamente.
#    🔤 [Pág 175] Texto extraído correctamente.
#    🔤 [Pág 176] Texto extraído correctamente.
#    🔤 [Pág 177] Texto extraído correctamente.
#    🔤 [Pág 178] Texto extraído correctamente.
#    🔤 [Pág 179] Texto extraído correctamente.
#    🔤 [Pág 180] Texto extraído correctamente.
#    🔤 [Pág 181] Texto extraído correctamente.
#    🔤 [Pág 182] Texto extraído correctamente.
#    🔤 [Pág 183] Texto extraído correctamente.
#    🔤 [Pág 184] Texto extraído correctamente.
#    🔤 [Pág 185] Texto extraído correctamente.
#    🔤 [Pág 186] Texto extraído correctamente.
#    🔤 [Pág 187] Texto extraído correctamente.
#    🔤 [Pág 188] Texto extraído correctamente.
#    🔤 [Pág 189] Texto extraído correctamente.
#    🔤 [Pág 190] Texto extraído correctamente.
#    🔤 [Pág 191] Texto extraído correctamente.
#    🔤 [Pág 192] Texto extraído correctamente.
#    🔤 [Pág 193] Texto extraído correctamente.
#    🔤 [Pág 194] Texto extraído correctamente.
#    🔤 [Pág 195] Texto extraído correctamente.
#    🔤 [Pág 196] Texto extraído correctamente.
#    🔤 [Pág 197] Texto extraído correctamente.
#    🔤 [Pág 198] Texto extraído correctamente.
#    🔤 [Pág 199] Texto extraído correctamente.
#    🔤 [Pág 200] Texto extraído correctamente.
#    🔤 [Pág 201] Texto extraído correctamente.
#    🔤 [Pág 202] Texto extraído correctamente.
#    🔤 [Pág 203] Texto extraído correctamente.
#    🔤 [Pág 204] Texto extraído correctamente.
#    🔤 [Pág 205] Texto extraído correctamente.
#    🔤 [Pág 206] Texto extraído correctamente.
#    🔤 [Pág 207] Texto extraído correctamente.
#    🔤 [Pág 208] Texto extraído correctamente.
#    🔤 [Pág 209] Texto extraído correctamente.
#    🔤 [Pág 210] Texto extraído correctamente.
#    🔤 [Pág 211] Texto extraído correctamente.
#    🔤 [Pág 212] Texto extraído correctamente.
#    🔤 [Pág 213] Texto extraído correctamente.
#    🔤 [Pág 214] Texto extraído correctamente.
#    🔤 [Pág 215] Texto extraído correctamente.
#    🔤 [Pág 216] Texto extraído correctamente.
#    🔤 [Pág 217] Texto extraído correctamente.
#    🔤 [Pág 218] Texto extraído correctamente.
#    🔤 [Pág 219] Texto extraído correctamente.
#    🔤 [Pág 220] Texto extraído correctamente.
#    🔤 [Pág 221] Texto extraído correctamente.
#    🔤 [Pág 222] Texto extraído correctamente.
#    🔤 [Pág 223] Texto extraído correctamente.
#    🔤 [Pág 224] Texto extraído correctamente.
#    🔤 [Pág 225] Texto extraído correctamente.
#    🔤 [Pág 226] Texto extraído correctamente.
#    🔤 [Pág 227] Texto extraído correctamente.
#    🔤 [Pág 228] Texto extraído correctamente.
#    🔤 [Pág 229] Texto extraído correctamente.
#    🔤 [Pág 230] Texto extraído correctamente.
#    🔤 [Pág 231] Texto extraído correctamente.
#    🔤 [Pág 232] Texto extraído correctamente.
#    🔤 [Pág 233] Texto extraído correctamente.
#    🔤 [Pág 234] Texto extraído correctamente.
#    🔤 [Pág 235] Texto extraído correctamente.
#    🔤 [Pág 236] Texto extraído correctamente.
#    🔤 [Pág 237] Texto extraído correctamente.
#    🔤 [Pág 238] Texto extraído correctamente.
#    🔤 [Pág 239] Texto extraído correctamente.
#    🔤 [Pág 240] Texto extraído correctamente.
#    🔤 [Pág 241] Texto extraído correctamente.
#    🔤 [Pág 242] Texto extraído correctamente.
#    🔤 [Pág 243] Texto extraído correctamente.
#    🔤 [Pág 244] Texto extraído correctamente.
#    🔤 [Pág 245] Texto extraído correctamente.
#    🔤 [Pág 246] Texto extraído correctamente.
#    🔤 [Pág 247] Texto extraído correctamente.
#    🔤 [Pág 248] Texto extraído correctamente.
#    🔤 [Pág 249] Texto extraído correctamente.
#    🔤 [Pág 250] Texto extraído correctamente.
#    🔤 [Pág 251] Texto extraído correctamente.
#    🔤 [Pág 252] Texto extraído correctamente.
#    🔤 [Pág 253] Texto extraído correctamente.
#    🔤 [Pág 254] Texto extraído correctamente.
#    🔤 [Pág 255] Texto extraído correctamente.
#    🔤 [Pág 256] Texto extraído correctamente.
#    🔤 [Pág 257] Texto extraído correctamente.
#    🔤 [Pág 258] Texto extraído correctamente.
#    🔤 [Pág 259] Texto extraído correctamente.
#    🔤 [Pág 260] Texto extraído correctamente.
#    🔤 [Pág 261] Texto extraído correctamente.
#    🔤 [Pág 262] Texto extraído correctamente.
#    🔤 [Pág 263] Texto extraído correctamente.
#    🔤 [Pág 264] Texto extraído correctamente.
#    🔤 [Pág 265] Texto extraído correctamente.
#    🔤 [Pág 266] Texto extraído correctamente.
#    🔤 [Pág 267] Texto extraído correctamente.
#    🔤 [Pág 268] Texto extraído correctamente.
#    🔤 [Pág 269] Texto extraído correctamente.
#    🔤 [Pág 270] Texto extraído correctamente.
#    🔤 [Pág 271] Texto extraído correctamente.
#    🔤 [Pág 272] Texto extraído correctamente.
#    🔤 [Pág 273] Texto extraído correctamente.
#    🔤 [Pág 274] Texto extraído correctamente.
#    🔤 [Pág 275] Texto extraído correctamente.
#    🔤 [Pág 276] Texto extraído correctamente.
#    🔤 [Pág 277] Texto extraído correctamente.
#    🔤 [Pág 278] Texto extraído correctamente.
#    🔤 [Pág 279] Texto extraído correctamente.
#    🔤 [Pág 280] Texto extraído correctamente.
#    🔤 [Pág 281] Texto extraído correctamente.
#    🔤 [Pág 282] Texto extraído correctamente.
#    🔤 [Pág 283] Texto extraído correctamente.
#    🔤 [Pág 284] Texto extraído correctamente.
#    🔤 [Pág 285] Texto extraído correctamente.
#    🔤 [Pág 286] Texto extraído correctamente.
#    🔤 [Pág 287] Texto extraído correctamente.
#    🔤 [Pág 288] Texto extraído correctamente.
#    🔤 [Pág 289] Texto extraído correctamente.
#    🔤 [Pág 290] Texto extraído correctamente.
#    🔤 [Pág 291] Texto extraído correctamente.
#    🔤 [Pág 292] Texto extraído correctamente.
#    🔤 [Pág 293] Texto extraído correctamente.
#    🔤 [Pág 294] Texto extraído correctamente.
#    🔤 [Pág 295] Texto extraído correctamente.
#    🔤 [Pág 296] Texto extraído correctamente.
#    🔤 [Pág 297] Texto extraído correctamente.
#    🔤 [Pág 298] Texto extraído correctamente.
#    🔤 [Pág 299] Texto extraído correctamente.
#    🔤 [Pág 300] Texto extraído correctamente.
#    🔤 [Pág 301] Texto extraído correctamente.
#    🔤 [Pág 302] Texto extraído correctamente.
#    🔤 [Pág 303] Texto extraído correctamente.
#    🔤 [Pág 304] Texto extraído correctamente.
#    🔤 [Pág 305] Texto extraído correctamente.
#    🔤 [Pág 306] Texto extraído correctamente.
#    🔤 [Pág 307] Texto extraído correctamente.
#    🔤 [Pág 308] Texto extraído correctamente.
#    🔤 [Pág 309] Texto extraído correctamente.
#    🔤 [Pág 310] Texto extraído correctamente.
#    🔤 [Pág 311] Texto extraído correctamente.
#    🔤 [Pág 312] Texto extraído correctamente.
#    🔤 [Pág 313] Texto extraído correctamente.
#    🔤 [Pág 314] Texto extraído correctamente.
#    🔤 [Pág 315] Texto extraído correctamente.
#    🔤 [Pág 316] Texto extraído correctamente.
#    🔤 [Pág 317] Texto extraído correctamente.
#    🔤 [Pág 318] Texto extraído correctamente.
#    🔤 [Pág 319] Texto extraído correctamente.
#    🔤 [Pág 320] Texto extraído correctamente.
#    🔤 [Pág 321] Texto extraído correctamente.
#    🔤 [Pág 322] Texto extraído correctamente.
#    🔤 [Pág 323] Texto extraído correctamente.
#    🔤 [Pág 324] Texto extraído correctamente.
#    🔤 [Pág 325] Texto extraído correctamente.
#    🔤 [Pág 326] Texto extraído correctamente.
#    🔤 [Pág 327] Texto extraído correctamente.
#    🔤 [Pág 328] Texto extraído correctamente.
#    🔤 [Pág 329] Texto extraído correctamente.
#    🔤 [Pág 330] Texto extraído correctamente.
#    🔤 [Pág 331] Texto extraído correctamente.
#    🔤 [Pág 332] Texto extraído correctamente.
#    🔤 [Pág 333] Texto extraído correctamente.
#    🔤 [Pág 334] Texto extraído correctamente.
#    🔤 [Pág 335] Texto extraído correctamente.
#    🔤 [Pág 336] Texto extraído correctamente.
#    🔤 [Pág 337] Texto extraído correctamente.
#    🔤 [Pág 338] Texto extraído correctamente.
#    🔤 [Pág 339] Texto extraído correctamente.
#    🔤 [Pág 340] Texto extraído correctamente.
#    🔤 [Pág 341] Texto extraído correctamente.
#    🔤 [Pág 342] Texto extraído correctamente.
#    🔤 [Pág 343] Texto extraído correctamente.
#    🔤 [Pág 344] Texto extraído correctamente.
#    🔤 [Pág 345] Texto extraído correctamente.
#    🔤 [Pág 346] Texto extraído correctamente.
#    🔤 [Pág 347] Texto extraído correctamente.
#    🔤 [Pág 348] Texto extraído correctamente.
#    🔤 [Pág 349] Texto extraído correctamente.
#    🔤 [Pág 350] Texto extraído correctamente.
#    🔤 [Pág 351] Texto extraído correctamente.
#    🔤 [Pág 352] Texto extraído correctamente.
#    🔤 [Pág 353] Texto extraído correctamente.
#    🔤 [Pág 354] Texto extraído correctamente.
#    🔤 [Pág 355] Texto extraído correctamente.
#    🔤 [Pág 356] Texto extraído correctamente.
#    🔤 [Pág 357] Texto extraído correctamente.
#    🔤 [Pág 358] Texto extraído correctamente.
#    🔤 [Pág 359] Texto extraído correctamente.
#    🔤 [Pág 360] Texto extraído correctamente.
#    🔤 [Pág 361] Texto extraído correctamente.
#    🔤 [Pág 362] Texto extraído correctamente.
#    🔤 [Pág 363] Texto extraído correctamente.
#    🔤 [Pág 364] Texto extraído correctamente.
#    🔤 [Pág 365] Texto extraído correctamente.
#    🔤 [Pág 366] Texto extraído correctamente.
#    🔤 [Pág 367] Texto extraído correctamente.
#    🔤 [Pág 368] Texto extraído correctamente.
#    🔤 [Pág 369] Texto extraído correctamente.
#    🔤 [Pág 370] Texto extraído correctamente.
#    🔤 [Pág 371] Texto extraído correctamente.
#    🔤 [Pág 372] Texto extraído correctamente.
#    🔤 [Pág 373] Texto extraído correctamente.
#    🔤 [Pág 374] Texto extraído correctamente.
#    🔤 [Pág 375] Texto extraído correctamente.
#    🔤 [Pág 376] Texto extraído correctamente.
#    🔤 [Pág 377] Texto extraído correctamente.
#    🔤 [Pág 378] Texto extraído correctamente.
#    🔤 [Pág 379] Texto extraído correctamente.
#    🔤 [Pág 380] Texto extraído correctamente.
#    🔤 [Pág 381] Texto extraído correctamente.
#    🔤 [Pág 382] Texto extraído correctamente.
#    🔤 [Pág 383] Texto extraído correctamente.
#    🔤 [Pág 384] Texto extraído correctamente.
#    🔤 [Pág 385] Texto extraído correctamente.
#    🔤 [Pág 386] Texto extraído correctamente.
#    🔤 [Pág 387] Texto extraído correctamente.
#    🔤 [Pág 388] Texto extraído correctamente.
#    🔤 [Pág 389] Texto extraído correctamente.
#    🔤 [Pág 390] Texto extraído correctamente.
#    🔤 [Pág 391] Texto extraído correctamente.
#    🔤 [Pág 392] Texto extraído correctamente.
#    🔤 [Pág 393] Texto extraído correctamente.
#    🔤 [Pág 394] Texto extraído correctamente.
#    🔤 [Pág 395] Texto extraído correctamente.
#    🔤 [Pág 396] Texto extraído correctamente.
#    🔤 [Pág 397] Texto extraído correctamente.
#    🔤 [Pág 398] Texto extraído correctamente.
#    🔤 [Pág 399] Texto extraído correctamente.
#    🔤 [Pág 400] Texto extraído correctamente.
#    🔤 [Pág 401] Texto extraído correctamente.
#    🔤 [Pág 402] Texto extraído correctamente.
#    🔤 [Pág 403] Texto extraído correctamente.
#    🔤 [Pág 404] Texto extraído correctamente.
#    🔤 [Pág 405] Texto extraído correctamente.
#    🔤 [Pág 406] Texto extraído correctamente.
#    🔤 [Pág 407] Texto extraído correctamente.
#    🔤 [Pág 408] Texto extraído correctamente.
#    🔤 [Pág 409] Texto extraído correctamente.
#    🔤 [Pág 410] Texto extraído correctamente.
#    🔤 [Pág 411] Texto extraído correctamente.
#    🔤 [Pág 412] Texto extraído correctamente.
#    🔤 [Pág 413] Texto extraído correctamente.
#    🔤 [Pág 414] Texto extraído correctamente.
#    🔤 [Pág 415] Texto extraído correctamente.
#    🔤 [Pág 416] Texto extraído correctamente.
#    🔤 [Pág 417] Texto extraído correctamente.
#    🔤 [Pág 418] Texto extraído correctamente.
#    🔤 [Pág 419] Texto extraído correctamente.
#    🔤 [Pág 420] Texto extraído correctamente.
#    🔤 [Pág 421] Texto extraído correctamente.
#    🔤 [Pág 422] Texto extraído correctamente.
#    🔤 [Pág 423] Texto extraído correctamente.
#    🔤 [Pág 424] Texto extraído correctamente.
#    🔤 [Pág 425] Texto extraído correctamente.
#    🔤 [Pág 426] Texto extraído correctamente.
#    🔤 [Pág 427] Texto extraído correctamente.
#    🔤 [Pág 428] Texto extraído correctamente.
#    🔤 [Pág 429] Texto extraído correctamente.
#    🔤 [Pág 430] Texto extraído correctamente.
#    🔤 [Pág 431] Texto extraído correctamente.
#    🔤 [Pág 432] Texto extraído correctamente.
#    🔤 [Pág 433] Texto extraído correctamente.
#    🔤 [Pág 434] Texto extraído correctamente.
#    🔤 [Pág 435] Texto extraído correctamente.
#    🔤 [Pág 436] Texto extraído correctamente.
#    🔤 [Pág 437] Texto extraído correctamente.
#    🔤 [Pág 438] Texto extraído correctamente.
#    🔤 [Pág 439] Texto extraído correctamente.
#    🔤 [Pág 440] Texto extraído correctamente.
#    🔤 [Pág 441] Texto extraído correctamente.
#    🔤 [Pág 442] Texto extraído correctamente.
#    🔤 [Pág 443] Texto extraído correctamente.
#    🔤 [Pág 444] Texto extraído correctamente.
#    🔤 [Pág 445] Texto extraído correctamente.
#    🔤 [Pág 446] Texto extraído correctamente.
#    🔤 [Pág 447] Texto extraído correctamente.
#    🔤 [Pág 448] Texto extraído correctamente.
#    🔤 [Pág 449] Texto extraído correctamente.
#    🔤 [Pág 450] Texto extraído correctamente.
#    🔤 [Pág 451] Texto extraído correctamente.
#    🔤 [Pág 452] Texto extraído correctamente.
#    🔤 [Pág 453] Texto extraído correctamente.
#    🔤 [Pág 454] Texto extraído correctamente.
#    🔤 [Pág 455] Texto extraído correctamente.
#    🔤 [Pág 456] Texto extraído correctamente.
#    🔤 [Pág 457] Texto extraído correctamente.
#    🔤 [Pág 458] Texto extraído correctamente.
#    🔤 [Pág 459] Texto extraído correctamente.
#    🔤 [Pág 460] Texto extraído correctamente.
#    🔤 [Pág 461] Texto extraído correctamente.
#    🔤 [Pág 462] Texto extraído correctamente.
#    🔤 [Pág 463] Texto extraído correctamente.
#    🔤 [Pág 464] Texto extraído correctamente.
#    🔤 [Pág 465] Texto extraído correctamente.
#    🔤 [Pág 466] Texto extraído correctamente.
#    🔤 [Pág 467] Texto extraído correctamente.
#    🔤 [Pág 468] Texto extraído correctamente.
#    🔤 [Pág 469] Texto extraído correctamente.
#    🔤 [Pág 470] Texto extraído correctamente.
#    🔤 [Pág 471] Texto extraído correctamente.
#    🔤 [Pág 472] Texto extraído correctamente.
#    🔤 [Pág 473] Texto extraído correctamente.
#    🔤 [Pág 474] Texto extraído correctamente.
#    🔤 [Pág 475] Texto extraído correctamente.
#    🔤 [Pág 476] Texto extraído correctamente.
#    🔤 [Pág 477] Texto extraído correctamente.
#    🔤 [Pág 478] Texto extraído correctamente.
#    🔤 [Pág 479] Texto extraído correctamente.
#    🔤 [Pág 480] Texto extraído correctamente.
#    🔤 [Pág 481] Texto extraído correctamente.
#    🔤 [Pág 482] Texto extraído correctamente.
#    🔤 [Pág 483] Texto extraído correctamente.
#    🔤 [Pág 484] Texto extraído correctamente.
#    🔤 [Pág 485] Texto extraído correctamente.
#    🔤 [Pág 486] Texto extraído correctamente.
#    🔤 [Pág 487] Texto extraído correctamente.
#    🔤 [Pág 488] Texto extraído correctamente.
#    🔤 [Pág 489] Texto extraído correctamente.
#    🔤 [Pág 490] Texto extraído correctamente.
#    🔤 [Pág 491] Texto extraído correctamente.
#    🔤 [Pág 492] Texto extraído correctamente.
#    🔤 [Pág 493] Texto extraído correctamente.
#    🔤 [Pág 494] Texto extraído correctamente.
#    🔤 [Pág 495] Texto extraído correctamente.
#    🔤 [Pág 496] Texto extraído correctamente.
#    🔤 [Pág 497] Texto extraído correctamente.
#    🔤 [Pág 498] Texto extraído correctamente.
#    🔤 [Pág 499] Texto extraído correctamente.
#    🔤 [Pág 500] Texto extraído correctamente.
#    🔤 [Pág 501] Texto extraído correctamente.
#    🔤 [Pág 502] Texto extraído correctamente.
#    🔤 [Pág 503] Texto extraído correctamente.
#    🔤 [Pág 504] Texto extraído correctamente.
#    🔤 [Pág 505] Texto extraído correctamente.
#    🔤 [Pág 506] Texto extraído correctamente.
#    🔤 [Pág 507] Texto extraído correctamente.
#    🔤 [Pág 508] Texto extraído correctamente.
#    🔤 [Pág 509] Texto extraído correctamente.
#    🔤 [Pág 510] Texto extraído correctamente.
#    🔤 [Pág 511] Texto extraído correctamente.
#    🔤 [Pág 512] Texto extraído correctamente.
#    🔤 [Pág 513] Texto extraído correctamente.
#    🔤 [Pág 514] Texto extraído correctamente.
#    🔤 [Pág 515] Texto extraído correctamente.
#    🔤 [Pág 516] Texto extraído correctamente.
#    🔤 [Pág 517] Texto extraído correctamente.
#    🔤 [Pág 518] Texto extraído correctamente.
#    🔤 [Pág 519] Texto extraído correctamente.
#    🔤 [Pág 520] Texto extraído correctamente.
#    🔤 [Pág 521] Texto extraído correctamente.
#    🔤 [Pág 522] Texto extraído correctamente.
#    🔤 [Pág 523] Texto extraído correctamente.
#    🔤 [Pág 524] Texto extraído correctamente.
#    🔤 [Pág 525] Texto extraído correctamente.
#    🔤 [Pág 526] Texto extraído correctamente.
#    🔤 [Pág 527] Texto extraído correctamente.
#    🔤 [Pág 528] Texto extraído correctamente.
#    🔤 [Pág 529] Texto extraído correctamente.
#    🔤 [Pág 530] Texto extraído correctamente.
#    🔤 [Pág 531] Texto extraído correctamente.
#    🔤 [Pág 532] Texto extraído correctamente.
#    🔤 [Pág 533] Texto extraído correctamente.
#    🔤 [Pág 534] Texto extraído correctamente.
#    🔤 [Pág 535] Texto extraído correctamente.
#    🔤 [Pág 536] Texto extraído correctamente.
#    🔤 [Pág 537] Texto extraído correctamente.
#    🔤 [Pág 538] Texto extraído correctamente.
#    🔤 [Pág 539] Texto extraído correctamente.
#    🔤 [Pág 540] Texto extraído correctamente.
#    🔤 [Pág 541] Texto extraído correctamente.
#    🔤 [Pág 542] Texto extraído correctamente.
#    🔤 [Pág 543] Texto extraído correctamente.
#    🔤 [Pág 544] Texto extraído correctamente.
#    🔤 [Pág 545] Texto extraído correctamente.
#    🔤 [Pág 546] Texto extraído correctamente.
#    🔤 [Pág 547] Texto extraído correctamente.
#    🔤 [Pág 548] Texto extraído correctamente.
#    🔤 [Pág 549] Texto extraído correctamente.
#    🔤 [Pág 550] Texto extraído correctamente.
#    🔤 [Pág 551] Texto extraído correctamente.
#    🔤 [Pág 552] Texto extraído correctamente.
#    🔤 [Pág 553] Texto extraído correctamente.
#    🔤 [Pág 554] Texto extraído correctamente.
#    🔤 [Pág 555] Texto extraído correctamente.
#    🔤 [Pág 556] Texto extraído correctamente.
#    🔤 [Pág 557] Texto extraído correctamente.
#    🔤 [Pág 558] Texto extraído correctamente.
#    🔤 [Pág 559] Texto extraído correctamente.
#    🔤 [Pág 560] Texto extraído correctamente.
#    🔤 [Pág 561] Texto extraído correctamente.
#    🔤 [Pág 562] Texto extraído correctamente.
#    🔤 [Pág 563] Texto extraído correctamente.
#    🔤 [Pág 564] Texto extraído correctamente.
#    🔤 [Pág 565] Texto extraído correctamente.
#    🔤 [Pág 566] Texto extraído correctamente.
#    🔤 [Pág 567] Texto extraído correctamente.
#    🔤 [Pág 568] Texto extraído correctamente.
#    🔤 [Pág 569] Texto extraído correctamente.
#    🔤 [Pág 570] Texto extraído correctamente.
#    🔤 [Pág 571] Texto extraído correctamente.
#    🔤 [Pág 572] Texto extraído correctamente.
#    🔤 [Pág 573] Texto extraído correctamente.
#    🔤 [Pág 574] Texto extraído correctamente.
#    🔤 [Pág 575] Texto extraído correctamente.
#    🔤 [Pág 576] Texto extraído correctamente.
#    🔤 [Pág 577] Texto extraído correctamente.
#    🔤 [Pág 578] Texto extraído correctamente.
#    🔤 [Pág 579] Texto extraído correctamente.
#    🔤 [Pág 580] Texto extraído correctamente.
#    🔤 [Pág 581] Texto extraído correctamente.
#    🔤 [Pág 582] Texto extraído correctamente.
#    🔤 [Pág 583] Texto extraído correctamente.
#    🔤 [Pág 584] Texto extraído correctamente.
#    🔤 [Pág 585] Texto extraído correctamente.
#    🔤 [Pág 586] Texto extraído correctamente.
#    🔤 [Pág 587] Texto extraído correctamente.
#    🔤 [Pág 588] Texto extraído correctamente.
#    🔤 [Pág 589] Texto extraído correctamente.
#    🔤 [Pág 590] Texto extraído correctamente.
#    🔤 [Pág 591] Texto extraído correctamente.
#    🔤 [Pág 592] Texto extraído correctamente.
#    🔤 [Pág 593] Texto extraído correctamente.
#    🔤 [Pág 594] Texto extraído correctamente.
#    🔤 [Pág 595] Texto extraído correctamente.
#    🔤 [Pág 596] Texto extraído correctamente.
#    🔤 [Pág 597] Texto extraído correctamente.
#    🔤 [Pág 598] Texto extraído correctamente.
#    🔤 [Pág 599] Texto extraído correctamente.
#    🔤 [Pág 600] Texto extraído correctamente.
#    🔤 [Pág 601] Texto extraído correctamente.
#    🔤 [Pág 602] Texto extraído correctamente.
#    🔤 [Pág 603] Texto extraído correctamente.
#    🔤 [Pág 604] Texto extraído correctamente.
#    🔤 [Pág 605] Texto extraído correctamente.
#    🔤 [Pág 606] Texto extraído correctamente.
#    🔤 [Pág 607] Texto extraído correctamente.
#    🔤 [Pág 608] Texto extraído correctamente.
#    🔤 [Pág 609] Texto extraído correctamente.
#    🔤 [Pág 610] Texto extraído correctamente.
#    🔤 [Pág 611] Texto extraído correctamente.
#    🔤 [Pág 612] Texto extraído correctamente.
#    🔤 [Pág 613] Texto extraído correctamente.
#    🔤 [Pág 614] Texto extraído correctamente.
#    🔤 [Pág 615] Texto extraído correctamente.
#    🔤 [Pág 616] Texto extraído correctamente.
#    🔤 [Pág 617] Texto extraído correctamente.
#    🔤 [Pág 618] Texto extraído correctamente.
#    🔤 [Pág 619] Texto extraído correctamente.
#    🔤 [Pág 620] Texto extraído correctamente.
#    🔤 [Pág 621] Texto extraído correctamente.
#    🔤 [Pág 622] Texto extraído correctamente.
#    🔤 [Pág 623] Texto extraído correctamente.
#    🔤 [Pág 624] Texto extraído correctamente.
#    🔤 [Pág 625] Texto extraído correctamente.
#    🔤 [Pág 626] Texto extraído correctamente.
#    🔤 [Pág 627] Texto extraído correctamente.
#    🔤 [Pág 628] Texto extraído correctamente.
#    🔤 [Pág 629] Texto extraído correctamente.
#    🔤 [Pág 630] Texto extraído correctamente.
#    🔤 [Pág 631] Texto extraído correctamente.
#    🔤 [Pág 632] Texto extraído correctamente.
#    🔤 [Pág 633] Texto extraído correctamente.
#    🔤 [Pág 634] Texto extraído correctamente.
#    🔤 [Pág 635] Texto extraído correctamente.
#    🔤 [Pág 636] Texto extraído correctamente.
#    🔤 [Pág 637] Texto extraído correctamente.
#    🔤 [Pág 638] Texto extraído correctamente.
#    🔤 [Pág 639] Texto extraído correctamente.
#    🔤 [Pág 640] Texto extraído correctamente.
#    🔤 [Pág 641] Texto extraído correctamente.
#    🔤 [Pág 642] Texto extraído correctamente.
#    🔤 [Pág 643] Texto extraído correctamente.
#    🔤 [Pág 644] Texto extraído correctamente.
#    🔤 [Pág 645] Texto extraído correctamente.
#    🔤 [Pág 646] Texto extraído correctamente.
#    🔤 [Pág 647] Texto extraído correctamente.
#    🔤 [Pág 648] Texto extraído correctamente.
#    🔤 [Pág 649] Texto extraído correctamente.
#    🔤 [Pág 650] Texto extraído correctamente.
#    🔤 [Pág 651] Texto extraído correctamente.
#    🔤 [Pág 652] Texto extraído correctamente.
#    🔤 [Pág 653] Texto extraído correctamente.
#    🔤 [Pág 654] Texto extraído correctamente.
#    🔤 [Pág 655] Texto extraído correctamente.
#    🔤 [Pág 656] Texto extraído correctamente.
#    🔤 [Pág 657] Texto extraído correctamente.
#    🔤 [Pág 658] Texto extraído correctamente.
#    🔤 [Pág 659] Texto extraído correctamente.
#    🔤 [Pág 660] Texto extraído correctamente.
#    🔤 [Pág 661] Texto extraído correctamente.
#    🔤 [Pág 662] Texto extraído correctamente.
#    🔤 [Pág 663] Texto extraído correctamente.
#    🔤 [Pág 664] Texto extraído correctamente.
#    🔤 [Pág 665] Texto extraído correctamente.
#    🔤 [Pág 666] Texto extraído correctamente.
#    🔤 [Pág 667] Texto extraído correctamente.
#    🔤 [Pág 668] Texto extraído correctamente.
#    🔤 [Pág 669] Texto extraído correctamente.
#    🔤 [Pág 670] Texto extraído correctamente.
#    🔤 [Pág 671] Texto extraído correctamente.
#    🔤 [Pág 672] Texto extraído correctamente.
#    🔤 [Pág 673] Texto extraído correctamente.
#    🔤 [Pág 674] Texto extraído correctamente.
#    🔤 [Pág 675] Texto extraído correctamente.
#    🔤 [Pág 676] Texto extraído correctamente.
#    🔤 [Pág 677] Texto extraído correctamente.
#    🔤 [Pág 678] Texto extraído correctamente.
#    🔤 [Pág 679] Texto extraído correctamente.
#    🔤 [Pág 680] Texto extraído correctamente.
#    🔤 [Pág 681] Texto extraído correctamente.
#    🔤 [Pág 682] Texto extraído correctamente.
#    🔤 [Pág 683] Texto extraído correctamente.
#    🔤 [Pág 684] Texto extraído correctamente.
#    🔤 [Pág 685] Texto extraído correctamente.
#    🔤 [Pág 686] Texto extraído correctamente.
#    🔤 [Pág 687] Texto extraído correctamente.
#    🔤 [Pág 688] Texto extraído correctamente.
#    🔤 [Pág 689] Texto extraído correctamente.
#    🔤 [Pág 690] Texto extraído correctamente.
#    🔤 [Pág 691] Texto extraído correctamente.
#    🔤 [Pág 692] Texto extraído correctamente.
#    🔤 [Pág 693] Texto extraído correctamente.
#    🔤 [Pág 694] Texto extraído correctamente.
#    🔤 [Pág 695] Texto extraído correctamente.
#    🔤 [Pág 696] Texto extraído correctamente.
#    🔤 [Pág 697] Texto extraído correctamente.
#    🔤 [Pág 698] Texto extraído correctamente.
#    🔤 [Pág 699] Texto extraído correctamente.
#    🔤 [Pág 700] Texto extraído correctamente.
#    🔤 [Pág 701] Texto extraído correctamente.
#    🔤 [Pág 702] Texto extraído correctamente.
#    🔤 [Pág 703] Texto extraído correctamente.
#    🔤 [Pág 704] Texto extraído correctamente.
#    🔤 [Pág 705] Texto extraído correctamente.
#    🔤 [Pág 706] Texto extraído correctamente.
#    🔤 [Pág 707] Texto extraído correctamente.
#    🔤 [Pág 708] Texto extraído correctamente.
#    🔤 [Pág 709] Texto extraído correctamente.
#    🔤 [Pág 710] Texto extraído correctamente.
#    🔤 [Pág 711] Texto extraído correctamente.
#    🔤 [Pág 712] Texto extraído correctamente.
#    🔤 [Pág 713] Texto extraído correctamente.
#    🔤 [Pág 714] Texto extraído correctamente.
#    🔤 [Pág 715] Texto extraído correctamente.
#    🔤 [Pág 716] Texto extraído correctamente.
#    🔤 [Pág 717] Texto extraído correctamente.
#    🔤 [Pág 718] Texto extraído correctamente.
#    🔤 [Pág 719] Texto extraído correctamente.
#    🔤 [Pág 720] Texto extraído correctamente.
#    🔤 [Pág 721] Texto extraído correctamente.
#    🔤 [Pág 722] Texto extraído correctamente.
#    🔤 [Pág 723] Texto extraído correctamente.
#    🔤 [Pág 724] Texto extraído correctamente.
#    🔤 [Pág 725] Texto extraído correctamente.
#    🔤 [Pág 726] Texto extraído correctamente.
#
# 📄 Procesando PDF (Modo Texto Rápido): BOE-A-2004-18911-consolidado.pdf
#    🔤 [Pág 1] Texto extraído correctamente.
#    🔤 [Pág 2] Texto extraído correctamente.
#    🔤 [Pág 3] Texto extraído correctamente.
#    🔤 [Pág 4] Texto extraído correctamente.
#    🔤 [Pág 5] Texto extraído correctamente.
#    🔤 [Pág 6] Texto extraído correctamente.
#    🔤 [Pág 7] Texto extraído correctamente.
#    🔤 [Pág 8] Texto extraído correctamente.
#    🔤 [Pág 9] Texto extraído correctamente.
#    🔤 [Pág 10] Texto extraído correctamente.
#    🔤 [Pág 11] Texto extraído correctamente.
#    🔤 [Pág 12] Texto extraído correctamente.
#    🔤 [Pág 13] Texto extraído correctamente.
#    🔤 [Pág 14] Texto extraído correctamente.
#    🔤 [Pág 15] Texto extraído correctamente.
#    🔤 [Pág 16] Texto extraído correctamente.
#    🔤 [Pág 17] Texto extraído correctamente.
#    🔤 [Pág 18] Texto extraído correctamente.
#    🔤 [Pág 19] Texto extraído correctamente.
#    🔤 [Pág 20] Texto extraído correctamente.
#    🔤 [Pág 21] Texto extraído correctamente.
#    🔤 [Pág 22] Texto extraído correctamente.
#    🔤 [Pág 23] Texto extraído correctamente.
#    🔤 [Pág 24] Texto extraído correctamente.
#    🔤 [Pág 25] Texto extraído correctamente.
#    🔤 [Pág 26] Texto extraído correctamente.
#    🔤 [Pág 27] Texto extraído correctamente.
#    🔤 [Pág 28] Texto extraído correctamente.
#    🔤 [Pág 29] Texto extraído correctamente.
#    🔤 [Pág 30] Texto extraído correctamente.
#    🔤 [Pág 31] Texto extraído correctamente.
#    🔤 [Pág 32] Texto extraído correctamente.
#    🔤 [Pág 33] Texto extraído correctamente.
#    🔤 [Pág 34] Texto extraído correctamente.
#    🔤 [Pág 35] Texto extraído correctamente.
#    🔤 [Pág 36] Texto extraído correctamente.
#    🔤 [Pág 37] Texto extraído correctamente.
#    🔤 [Pág 38] Texto extraído correctamente.
#    🔤 [Pág 39] Texto extraído correctamente.
#    🔤 [Pág 40] Texto extraído correctamente.
#    🔤 [Pág 41] Texto extraído correctamente.
#    🔤 [Pág 42] Texto extraído correctamente.
#    🔤 [Pág 43] Texto extraído correctamente.
#    🔤 [Pág 44] Texto extraído correctamente.
#    🔤 [Pág 45] Texto extraído correctamente.
#    🔤 [Pág 46] Texto extraído correctamente.
#    🔤 [Pág 47] Texto extraído correctamente.
#    🔤 [Pág 48] Texto extraído correctamente.
#    🔤 [Pág 49] Texto extraído correctamente.
#    🔤 [Pág 50] Texto extraído correctamente.
#    🔤 [Pág 51] Texto extraído correctamente.
#    🔤 [Pág 52] Texto extraído correctamente.
#    🔤 [Pág 53] Texto extraído correctamente.
#    🔤 [Pág 54] Texto extraído correctamente.
#    🔤 [Pág 55] Texto extraído correctamente.
#    🔤 [Pág 56] Texto extraído correctamente.
#    🔤 [Pág 57] Texto extraído correctamente.
#    🔤 [Pág 58] Texto extraído correctamente.
#    🔤 [Pág 59] Texto extraído correctamente.
#    🔤 [Pág 60] Texto extraído correctamente.
#    🔤 [Pág 61] Texto extraído correctamente.
#    🔤 [Pág 62] Texto extraído correctamente.
#    🔤 [Pág 63] Texto extraído correctamente.
#    🔤 [Pág 64] Texto extraído correctamente.
#    🔤 [Pág 65] Texto extraído correctamente.
#    🔤 [Pág 66] Texto extraído correctamente.
#    🔤 [Pág 67] Texto extraído correctamente.
#    🔤 [Pág 68] Texto extraído correctamente.
#    🔤 [Pág 69] Texto extraído correctamente.
#    🔤 [Pág 70] Texto extraído correctamente.
#    🔤 [Pág 71] Texto extraído correctamente.
#    🔤 [Pág 72] Texto extraído correctamente.
#    🔤 [Pág 73] Texto extraído correctamente.
#    🔤 [Pág 74] Texto extraído correctamente.
#    🔤 [Pág 75] Texto extraído correctamente.
#    🔤 [Pág 76] Texto extraído correctamente.
#    🔤 [Pág 77] Texto extraído correctamente.
#    🔤 [Pág 78] Texto extraído correctamente.
#    🔤 [Pág 79] Texto extraído correctamente.
#    🔤 [Pág 80] Texto extraído correctamente.
#    🔤 [Pág 81] Texto extraído correctamente.
#    🔤 [Pág 82] Texto extraído correctamente.
#    🔤 [Pág 83] Texto extraído correctamente.
#    🔤 [Pág 84] Texto extraído correctamente.
#    🔤 [Pág 85] Texto extraído correctamente.
#    🔤 [Pág 86] Texto extraído correctamente.
#    🔤 [Pág 87] Texto extraído correctamente.
#    🔤 [Pág 88] Texto extraído correctamente.
#    🔤 [Pág 89] Texto extraído correctamente.
#    🔤 [Pág 90] Texto extraído correctamente.
#    🔤 [Pág 91] Texto extraído correctamente.
#    🔤 [Pág 92] Texto extraído correctamente.
#    🔤 [Pág 93] Texto extraído correctamente.
#    🔤 [Pág 94] Texto extraído correctamente.
#    🔤 [Pág 95] Texto extraído correctamente.
#    🔤 [Pág 96] Texto extraído correctamente.
#    🔤 [Pág 97] Texto extraído correctamente.
#    🔤 [Pág 98] Texto extraído correctamente.
#    🔤 [Pág 99] Texto extraído correctamente.
#    🔤 [Pág 100] Texto extraído correctamente.
#    🔤 [Pág 101] Texto extraído correctamente.
#    🔤 [Pág 102] Texto extraído correctamente.
#    🔤 [Pág 103] Texto extraído correctamente.
#    🔤 [Pág 104] Texto extraído correctamente.
#    🔤 [Pág 105] Texto extraído correctamente.
#    🔤 [Pág 106] Texto extraído correctamente.
#    🔤 [Pág 107] Texto extraído correctamente.
#    🔤 [Pág 108] Texto extraído correctamente.
#    🔤 [Pág 109] Texto extraído correctamente.
#    🔤 [Pág 110] Texto extraído correctamente.
#    🔤 [Pág 111] Texto extraído correctamente.
#    🔤 [Pág 112] Texto extraído correctamente.
#    🔤 [Pág 113] Texto extraído correctamente.
#    🔤 [Pág 114] Texto extraído correctamente.
#    🔤 [Pág 115] Texto extraído correctamente.
#    🔤 [Pág 116] Texto extraído correctamente.
#    🔤 [Pág 117] Texto extraído correctamente.
#    🔤 [Pág 118] Texto extraído correctamente.
#    🔤 [Pág 119] Texto extraído correctamente.
#    🔤 [Pág 120] Texto extraído correctamente.
#    🔤 [Pág 121] Texto extraído correctamente.
#    🔤 [Pág 122] Texto extraído correctamente.
#    🔤 [Pág 123] Texto extraído correctamente.
#    🔤 [Pág 124] Texto extraído correctamente.
#    🔤 [Pág 125] Texto extraído correctamente.
#    🔤 [Pág 126] Texto extraído correctamente.
#    🔤 [Pág 127] Texto extraído correctamente.
#    🔤 [Pág 128] Texto extraído correctamente.
#    🔤 [Pág 129] Texto extraído correctamente.
#    🔤 [Pág 130] Texto extraído correctamente.
#    🔤 [Pág 131] Texto extraído correctamente.
#    🔤 [Pág 132] Texto extraído correctamente.
#    🔤 [Pág 133] Texto extraído correctamente.
#    🔤 [Pág 134] Texto extraído correctamente.
#    🔤 [Pág 135] Texto extraído correctamente.
#    🔤 [Pág 136] Texto extraído correctamente.
# ...
#    🔤 [Pág 70] Texto extraído correctamente.
#    🔤 [Pág 71] Texto extraído correctamente.
#    🔤 [Pág 72] Texto extraído correctamente.
#    🔤 [Pág 73] Texto extraído correctamente.
#    🔤 [Pág 74] Texto extraído correctamente.
#    🔤 [Pág 75] Texto extraído correctamente.
#    🔤 [Pág 76] Texto extraído correctamente.
#    🔤 [Pág 77] Texto extraído correctamente.
#    🔤 [Pág 78] Texto extraído correctamente.
#    🔤 [Pág 79] Texto extraído correctamente.
#    🔤 [Pág 80] Texto extraído correctamente.
#    🔤 [Pág 81] Texto extraído correctamente.
#    🔤 [Pág 82] Texto extraído correctamente.
#    🔤 [Pág 83] Texto extraído correctamente.
#    🔤 [Pág 84] Texto extraído correctamente.
#    🔤 [Pág 85] Texto extraído correctamente.
#    🔤 [Pág 86] Texto extraído correctamente.
#    🔤 [Pág 87] Texto extraído correctamente.
#    🔤 [Pág 88] Texto extraído correctamente.
#    🔤 [Pág 89] Texto extraído correctamente.
#    🔤 [Pág 90] Texto extraído correctamente.
#    🔤 [Pág 91] Texto extraído correctamente.
#    🔤 [Pág 92] Texto extraído correctamente.
#    🔤 [Pág 93] Texto extraído correctamente.
#    🔤 [Pág 94] Texto extraído correctamente.
#    🔤 [Pág 95] Texto extraído correctamente.
#    🔤 [Pág 96] Texto extraído correctamente.
#    🔤 [Pág 97] Texto extraído correctamente.
#    🔤 [Pág 98] Texto extraído correctamente.
#    🔤 [Pág 99] Texto extraído correctamente.
#    🔤 [Pág 100] Texto extraído correctamente.
#    🔤 [Pág 101] Texto extraído correctamente.
#    🔤 [Pág 102] Texto extraído correctamente.
#    🔤 [Pág 103] Texto extraído correctamente.
#    🔤 [Pág 104] Texto extraído correctamente.
#    🔤 [Pág 105] Texto extraído correctamente.
#    🔤 [Pág 106] Texto extraído correctamente.
#    🔤 [Pág 107] Texto extraído correctamente.
#    🔤 [Pág 108] Texto extraído correctamente.
#    🔤 [Pág 109] Texto extraído correctamente.
#    🔤 [Pág 110] Texto extraído correctamente.
#    🔤 [Pág 111] Texto extraído correctamente.
#    🔤 [Pág 112] Texto extraído correctamente.
#    🔤 [Pág 113] Texto extraído correctamente.
#    🔤 [Pág 114] Texto extraído correctamente.
#    ⚠️ [Pág 115] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    🔤 [Pág 116] Texto extraído correctamente.
#
# 📄 Procesando PDF (Modo Texto Rápido): Protocolo-Auxilio-en-Carretera.pdf
#    🔤 [Pág 1] Texto extraído correctamente.
#    🔤 [Pág 2] Texto extraído correctamente.
#    🔤 [Pág 3] Texto extraído correctamente.
#    🔤 [Pág 4] Texto extraído correctamente.
#    🔤 [Pág 5] Texto extraído correctamente.
#    🔤 [Pág 6] Texto extraído correctamente.
#    🔤 [Pág 7] Texto extraído correctamente.
#    🔤 [Pág 8] Texto extraído correctamente.
#    🔤 [Pág 9] Texto extraído correctamente.
#    🔤 [Pág 10] Texto extraído correctamente.
#    🔤 [Pág 11] Texto extraído correctamente.
#    🔤 [Pág 12] Texto extraído correctamente.
#    🔤 [Pág 13] Texto extraído correctamente.
#    🔤 [Pág 14] Texto extraído correctamente.
#    🔤 [Pág 15] Texto extraído correctamente.
#    🔤 [Pág 16] Texto extraído correctamente.
#    🔤 [Pág 17] Texto extraído correctamente.
#    🔤 [Pág 18] Texto extraído correctamente.
#    🔤 [Pág 19] Texto extraído correctamente.
#    🔤 [Pág 20] Texto extraído correctamente.
#    🔤 [Pág 21] Texto extraído correctamente.
#    🔤 [Pág 22] Texto extraído correctamente.
#    🔤 [Pág 23] Texto extraído correctamente.
#    🔤 [Pág 24] Texto extraído correctamente.
#    🔤 [Pág 25] Texto extraído correctamente.
#    🔤 [Pág 26] Texto extraído correctamente.
#    🔤 [Pág 27] Texto extraído correctamente.
#    🔤 [Pág 28] Texto extraído correctamente.
#    🔤 [Pág 29] Texto extraído correctamente.
#    🔤 [Pág 30] Texto extraído correctamente.
#    🔤 [Pág 31] Texto extraído correctamente.
#    🔤 [Pág 32] Texto extraído correctamente.
#    🔤 [Pág 33] Texto extraído correctamente.
#    🔤 [Pág 34] Texto extraído correctamente.
#    🔤 [Pág 35] Texto extraído correctamente.
#    🔤 [Pág 36] Texto extraído correctamente.
#    🔤 [Pág 37] Texto extraído correctamente.
#    ⚠️ [Pág 38] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 39] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 40] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 41] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 42] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 43] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 44] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 45] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 46] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 47] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 48] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 49] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 50] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 51] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 52] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 53] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 54] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 55] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 56] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    ⚠️ [Pág 57] Página sin texto digital (posiblemente un anexo gráfico o plano).
#
# 📄 Procesando PDF (Modo Texto Rápido): WEB_GUIA_AYUDA_AFECTADOS_SINIESTROS.pdf
#    🔤 [Pág 1] Texto extraído correctamente.
#    ⚠️ [Pág 2] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    🔤 [Pág 3] Texto extraído correctamente.
#    🔤 [Pág 4] Texto extraído correctamente.
#    🔤 [Pág 5] Texto extraído correctamente.
#    🔤 [Pág 6] Texto extraído correctamente.
#    🔤 [Pág 7] Texto extraído correctamente.
#    🔤 [Pág 8] Texto extraído correctamente.
#    🔤 [Pág 9] Texto extraído correctamente.
#    🔤 [Pág 10] Texto extraído correctamente.
#    🔤 [Pág 11] Texto extraído correctamente.
#    🔤 [Pág 12] Texto extraído correctamente.
#    🔤 [Pág 13] Texto extraído correctamente.
#    🔤 [Pág 14] Texto extraído correctamente.
#    🔤 [Pág 15] Texto extraído correctamente.
#    🔤 [Pág 16] Texto extraído correctamente.
#    🔤 [Pág 17] Texto extraído correctamente.
#    🔤 [Pág 18] Texto extraído correctamente.
#    🔤 [Pág 19] Texto extraído correctamente.
#    🔤 [Pág 20] Texto extraído correctamente.
#    🔤 [Pág 21] Texto extraído correctamente.
#    🔤 [Pág 22] Texto extraído correctamente.
#    🔤 [Pág 23] Texto extraído correctamente.
#    🔤 [Pág 24] Texto extraído correctamente.
#    🔤 [Pág 25] Texto extraído correctamente.
#    🔤 [Pág 26] Texto extraído correctamente.
#    🔤 [Pág 27] Texto extraído correctamente.
#    🔤 [Pág 28] Texto extraído correctamente.
#    🔤 [Pág 29] Texto extraído correctamente.
#    🔤 [Pág 30] Texto extraído correctamente.
#    🔤 [Pág 31] Texto extraído correctamente.
#    🔤 [Pág 32] Texto extraído correctamente.
#    🔤 [Pág 33] Texto extraído correctamente.
#    🔤 [Pág 34] Texto extraído correctamente.
#    🔤 [Pág 35] Texto extraído correctamente.
#    🔤 [Pág 36] Texto extraído correctamente.
#    🔤 [Pág 37] Texto extraído correctamente.
#    🔤 [Pág 38] Texto extraído correctamente.
#    🔤 [Pág 39] Texto extraído correctamente.
#    🔤 [Pág 40] Texto extraído correctamente.
#    🔤 [Pág 41] Texto extraído correctamente.
#    🔤 [Pág 42] Texto extraído correctamente.
#    🔤 [Pág 43] Texto extraído correctamente.
#    🔤 [Pág 44] Texto extraído correctamente.
#    🔤 [Pág 45] Texto extraído correctamente.
#    🔤 [Pág 46] Texto extraído correctamente.
#    🔤 [Pág 47] Texto extraído correctamente.
#    🔤 [Pág 48] Texto extraído correctamente.
#    🔤 [Pág 49] Texto extraído correctamente.
#    🔤 [Pág 50] Texto extraído correctamente.
#    🔤 [Pág 51] Texto extraído correctamente.
#    🔤 [Pág 52] Texto extraído correctamente.
#    🔤 [Pág 53] Texto extraído correctamente.
#    🔤 [Pág 54] Texto extraído correctamente.
#    🔤 [Pág 55] Texto extraído correctamente.
#    🔤 [Pág 56] Texto extraído correctamente.
#    🔤 [Pág 57] Texto extraído correctamente.
#    🔤 [Pág 58] Texto extraído correctamente.
#    🔤 [Pág 59] Texto extraído correctamente.
#    🔤 [Pág 60] Texto extraído correctamente.
#    🔤 [Pág 61] Texto extraído correctamente.
#    🔤 [Pág 62] Texto extraído correctamente.
#    🔤 [Pág 63] Texto extraído correctamente.
#    🔤 [Pág 64] Texto extraído correctamente.
#
# 📄 Procesando PDF (Modo Texto Rápido): manual_basico_rescate.pdf
#    🔤 [Pág 1] Texto extraído correctamente.
#    ⚠️ [Pág 2] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    🔤 [Pág 3] Texto extraído correctamente.
#    🔤 [Pág 4] Texto extraído correctamente.
#    🔤 [Pág 5] Texto extraído correctamente.
#    ⚠️ [Pág 6] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    🔤 [Pág 7] Texto extraído correctamente.
#    🔤 [Pág 8] Texto extraído correctamente.
#    🔤 [Pág 9] Texto extraído correctamente.
#    🔤 [Pág 10] Texto extraído correctamente.
#    🔤 [Pág 11] Texto extraído correctamente.
#    🔤 [Pág 12] Texto extraído correctamente.
#    🔤 [Pág 13] Texto extraído correctamente.
#    🔤 [Pág 14] Texto extraído correctamente.
#    🔤 [Pág 15] Texto extraído correctamente.
#    🔤 [Pág 16] Texto extraído correctamente.
#    🔤 [Pág 17] Texto extraído correctamente.
#    🔤 [Pág 18] Texto extraído correctamente.
#    🔤 [Pág 19] Texto extraído correctamente.
#    🔤 [Pág 20] Texto extraído correctamente.
#    🔤 [Pág 21] Texto extraído correctamente.
#    🔤 [Pág 22] Texto extraído correctamente.
#    🔤 [Pág 23] Texto extraído correctamente.
#    🔤 [Pág 24] Texto extraído correctamente.
#    🔤 [Pág 25] Texto extraído correctamente.
#    🔤 [Pág 26] Texto extraído correctamente.
#    🔤 [Pág 27] Texto extraído correctamente.
#    🔤 [Pág 28] Texto extraído correctamente.
#    🔤 [Pág 29] Texto extraído correctamente.
#    🔤 [Pág 30] Texto extraído correctamente.
#    🔤 [Pág 31] Texto extraído correctamente.
#    🔤 [Pág 32] Texto extraído correctamente.
#    🔤 [Pág 33] Texto extraído correctamente.
#    🔤 [Pág 34] Texto extraído correctamente.
#    🔤 [Pág 35] Texto extraído correctamente.
#    🔤 [Pág 36] Texto extraído correctamente.
#    🔤 [Pág 37] Texto extraído correctamente.
#    🔤 [Pág 38] Texto extraído correctamente.
#    🔤 [Pág 39] Texto extraído correctamente.
#    🔤 [Pág 40] Texto extraído correctamente.
#    🔤 [Pág 41] Texto extraído correctamente.
#    🔤 [Pág 42] Texto extraído correctamente.
#    🔤 [Pág 43] Texto extraído correctamente.
#    🔤 [Pág 44] Texto extraído correctamente.
#    🔤 [Pág 45] Texto extraído correctamente.
#    🔤 [Pág 46] Texto extraído correctamente.
#    🔤 [Pág 47] Texto extraído correctamente.
#    🔤 [Pág 48] Texto extraído correctamente.
#    🔤 [Pág 49] Texto extraído correctamente.
#    🔤 [Pág 50] Texto extraído correctamente.
#    🔤 [Pág 51] Texto extraído correctamente.
#    🔤 [Pág 52] Texto extraído correctamente.
#    🔤 [Pág 53] Texto extraído correctamente.
#    🔤 [Pág 54] Texto extraído correctamente.
#    🔤 [Pág 55] Texto extraído correctamente.
#    🔤 [Pág 56] Texto extraído correctamente.
#    🔤 [Pág 57] Texto extraído correctamente.
#    🔤 [Pág 58] Texto extraído correctamente.
#    🔤 [Pág 59] Texto extraído correctamente.
#    🔤 [Pág 60] Texto extraído correctamente.
#    🔤 [Pág 61] Texto extraído correctamente.
#    🔤 [Pág 62] Texto extraído correctamente.
#    🔤 [Pág 63] Texto extraído correctamente.
#    🔤 [Pág 64] Texto extraído correctamente.
#    🔤 [Pág 65] Texto extraído correctamente.
#    🔤 [Pág 66] Texto extraído correctamente.
#    🔤 [Pág 67] Texto extraído correctamente.
#    🔤 [Pág 68] Texto extraído correctamente.
#    🔤 [Pág 69] Texto extraído correctamente.
#    🔤 [Pág 70] Texto extraído correctamente.
#    🔤 [Pág 71] Texto extraído correctamente.
#    🔤 [Pág 72] Texto extraído correctamente.
#    🔤 [Pág 73] Texto extraído correctamente.
#    🔤 [Pág 74] Texto extraído correctamente.
#    🔤 [Pág 75] Texto extraído correctamente.
#    🔤 [Pág 76] Texto extraído correctamente.
#    🔤 [Pág 77] Texto extraído correctamente.
#    🔤 [Pág 78] Texto extraído correctamente.
#    🔤 [Pág 79] Texto extraído correctamente.
#    🔤 [Pág 80] Texto extraído correctamente.
#    🔤 [Pág 81] Texto extraído correctamente.
#    🔤 [Pág 82] Texto extraído correctamente.
#    🔤 [Pág 83] Texto extraído correctamente.
#    🔤 [Pág 84] Texto extraído correctamente.
#    🔤 [Pág 85] Texto extraído correctamente.
#    🔤 [Pág 86] Texto extraído correctamente.
#    🔤 [Pág 87] Texto extraído correctamente.
#    🔤 [Pág 88] Texto extraído correctamente.
#    🔤 [Pág 89] Texto extraído correctamente.
#    🔤 [Pág 90] Texto extraído correctamente.
#    🔤 [Pág 91] Texto extraído correctamente.
#    🔤 [Pág 92] Texto extraído correctamente.
#    🔤 [Pág 93] Texto extraído correctamente.
#    🔤 [Pág 94] Texto extraído correctamente.
#    🔤 [Pág 95] Texto extraído correctamente.
#    🔤 [Pág 96] Texto extraído correctamente.
#    🔤 [Pág 97] Texto extraído correctamente.
#    🔤 [Pág 98] Texto extraído correctamente.
#    🔤 [Pág 99] Texto extraído correctamente.
#    🔤 [Pág 100] Texto extraído correctamente.
#    🔤 [Pág 101] Texto extraído correctamente.
#    🔤 [Pág 102] Texto extraído correctamente.
#    🔤 [Pág 103] Texto extraído correctamente.
#    🔤 [Pág 104] Texto extraído correctamente.
#    🔤 [Pág 105] Texto extraído correctamente.
#    🔤 [Pág 106] Texto extraído correctamente.
#    🔤 [Pág 107] Texto extraído correctamente.
#    🔤 [Pág 108] Texto extraído correctamente.
#    🔤 [Pág 109] Texto extraído correctamente.
#    🔤 [Pág 110] Texto extraído correctamente.
#    🔤 [Pág 111] Texto extraído correctamente.
#    🔤 [Pág 112] Texto extraído correctamente.
#    🔤 [Pág 113] Texto extraído correctamente.
#    🔤 [Pág 114] Texto extraído correctamente.
#    🔤 [Pág 115] Texto extraído correctamente.
#    🔤 [Pág 116] Texto extraído correctamente.
#    🔤 [Pág 117] Texto extraído correctamente.
#    🔤 [Pág 118] Texto extraído correctamente.
#    🔤 [Pág 119] Texto extraído correctamente.
#    🔤 [Pág 120] Texto extraído correctamente.
#    🔤 [Pág 121] Texto extraído correctamente.
#    🔤 [Pág 122] Texto extraído correctamente.
#    🔤 [Pág 123] Texto extraído correctamente.
#    🔤 [Pág 124] Texto extraído correctamente.
#    🔤 [Pág 125] Texto extraído correctamente.
#    🔤 [Pág 126] Texto extraído correctamente.
#    🔤 [Pág 127] Texto extraído correctamente.
#    🔤 [Pág 128] Texto extraído correctamente.
#    🔤 [Pág 129] Texto extraído correctamente.
#    🔤 [Pág 130] Texto extraído correctamente.
#    🔤 [Pág 131] Texto extraído correctamente.
#    🔤 [Pág 132] Texto extraído correctamente.
#    🔤 [Pág 133] Texto extraído correctamente.
#    🔤 [Pág 134] Texto extraído correctamente.
#    🔤 [Pág 135] Texto extraído correctamente.
#    🔤 [Pág 136] Texto extraído correctamente.
#    🔤 [Pág 137] Texto extraído correctamente.
#    🔤 [Pág 138] Texto extraído correctamente.
#    🔤 [Pág 139] Texto extraído correctamente.
#    🔤 [Pág 140] Texto extraído correctamente.
#    🔤 [Pág 141] Texto extraído correctamente.
#    🔤 [Pág 142] Texto extraído correctamente.
#    🔤 [Pág 143] Texto extraído correctamente.
#    🔤 [Pág 144] Texto extraído correctamente.
#    🔤 [Pág 145] Texto extraído correctamente.
#    🔤 [Pág 146] Texto extraído correctamente.
#    🔤 [Pág 147] Texto extraído correctamente.
#    🔤 [Pág 148] Texto extraído correctamente.
#    🔤 [Pág 149] Texto extraído correctamente.
#    🔤 [Pág 150] Texto extraído correctamente.
#    🔤 [Pág 151] Texto extraído correctamente.
#    🔤 [Pág 152] Texto extraído correctamente.
#    🔤 [Pág 153] Texto extraído correctamente.
#    🔤 [Pág 154] Texto extraído correctamente.
#    🔤 [Pág 155] Texto extraído correctamente.
#    🔤 [Pág 156] Texto extraído correctamente.
#    🔤 [Pág 157] Texto extraído correctamente.
#    🔤 [Pág 158] Texto extraído correctamente.
#    🔤 [Pág 159] Texto extraído correctamente.
#    🔤 [Pág 160] Texto extraído correctamente.
#    🔤 [Pág 161] Texto extraído correctamente.
#    🔤 [Pág 162] Texto extraído correctamente.
#    🔤 [Pág 163] Texto extraído correctamente.
#    ⚠️ [Pág 164] Página sin texto digital (posiblemente un anexo gráfico o plano).
#    🔤 [Pág 165] Texto extraído correctamente.
#    🔤 [Pág 166] Texto extraído correctamente.
#
# ✅ Carga Rápida completada. Total páginas listas para ChromaDB: 2009

# %% [markdown]
# ## ✂️ Paso 5: Chunking de Alta Densidad Semántica

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=CHUNK_SIZE,
    chunk_overlap=CHUNK_OVERLAP,
    separators=["\n\n", "\n", ". ", " ", ""]
)

splits = text_splitter.split_documents(docs_totales)

print(f"📊 Estadísticas del chunking:")
print(f"   Documentos originales: {len(docs_totales)}")
print(f"   Chunks generados:      {len(splits)}")
print(f"   Avg chars/chunk:       {sum(len(c.page_content) for c in splits) // len(splits)}")
print(f"   Max chars/chunk:       {max(len(c.page_content) for c in splits)}")
print(f"   Min chars/chunk:       {min(len(c.page_content) for c in splits)}")

print(f"✂️ Documentos divididos con éxito en {len(splits)} fragmentos (chunks) vectorizables.")
# Out:
# 📊 Estadísticas del chunking:
#    Documentos originales: 2009
#    Chunks generados:      13282
#    Avg chars/chunk:       425
#    Max chars/chunk:       512
#    Min chars/chunk:       22
# ✂️ Documentos divididos con éxito en 13282 fragmentos (chunks) vectorizables.

# %% [markdown]
# ## 🗄️ Paso 6: Indexación en ChromaDB Local

# %%
embeddings = OllamaEmbeddings(model=EMBEDDING_MODEL, base_url=OLLAMA_BASE_URL)

print("Guardando vectores en base de datos local...")
vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,
    collection_name=COLLECTION_NAME,
    persist_directory=CHROMA_DIR,
    collection_metadata={"hnsw:space": "cosine"}
)

print(f"✅ ChromaDB persistido en: {CHROMA_DIR}")
# Out:
# Guardando vectores en base de datos local...
# ✅ ChromaDB persistido en: ../chroma_db/dgt_multimodal

# %% [markdown]
# ## 🧠 Paso 7: Pipeline RAG Edge (Inferencia Local)

# %%
# 1. Definimos el texto del prompt y lo GUARDAMOS en la variable prompt_template
prompt_template = """
Utiliza el siguiente contexto de los manuales de la DGT y el BOE para responder a la pregunta del conductor. 
Si no sabes la respuesta, di claramente que no lo sabes, no te inventes información.

Contexto de los manuales:
{context}

Pregunta del conductor: {question}

Respuesta de SafeDrive AI:"""

# 2. Ahora que la variable existe, LangChain ya la puede leer sin dar NameError
PROMPT = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)

# %%
# Formateador formal del contexto para auditoría visual por consola
def format_docs(docs):
    return "\n\n".join([f"[Origen: {d.metadata['source']} | Pág: {d.metadata['pagina']}]\n{d.page_content}" for d in docs])

# Construcción de la cadena LCEL
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | PROMPT
    | llm
    | StrOutputParser()
)

print("🚀 Pipeline de inferencia RAG Edge listo.")
# Out:
# 🚀 Pipeline de inferencia RAG Edge listo.

# %% [markdown]
# ## 📋 Paso 8: Pruebas de Estrés

# %%
def consultar_asistente(pregunta: str):
    print(f"\n🙋‍♂️ Conductor: {pregunta}")
    print("-" * 60)
    
    # Simulación previa del recuperador para la auditoría técnica por consola
    docs_recuperados = retriever.invoke(pregunta)
    print(f"🔍 Chunks recuperados matemáticamente: {len(docs_recuperados)}")
    for d in docs_recuperados:
        print(f"   - Fuente: {d.metadata['source']} (Pág. {d.metadata['pagina']})")
        
    # Inferencia de la cadena integrada
    respuesta = rag_chain.invoke(pregunta)
    print(f"\n🤖 SafeDrive AI:\n{respuesta}\n")
    print("=" * 80)

# --- EJECUCIÓN DE CASOS DE CONTROL DEL TFG ---
consultar_asistente("El otro conductor quiere que firme el parte en blanco para rellenarlo luego, ¿debo hacerlo?")
consultar_asistente("Tengo una hemorragia en el brazo tras el choque, ¿qué hago?")
consultar_asistente("He chocado en una curva donde había una señal triangular blanca con borde rojo. ¿Cómo pongo el vehículo de auxilio?")
# Out:
# 🙋‍♂️ Conductor: El otro conductor quiere que firme el parte en blanco para rellenarlo luego, ¿debo hacerlo?
# ------------------------------------------------------------
# 🔍 Chunks recuperados matemáticamente: 4
#    - Fuente: BOE-A-2015-11722-consolidado.pdf (Pág. 41)
#    - Fuente: BOE-A-2003-23514-consolidado.pdf (Pág. 56)
#    - Fuente: BOE-A-2015-11722-consolidado.pdf (Pág. 41)
#    - Fuente: BOE-A-2003-23514-consolidado.pdf (Pág. 23)
#
# 🤖 SafeDrive AI:
# No, no deberías firmar un parte de accidente en blanco. Es importante ser honesto y responsable en estos casos. Deberías firmar solo aquello que reconozcas como cierto o que hayas participado en la redacción. Si no has visto el accidente o no estás seguro sobre los detalles, es mejor no firmar nada hasta que puedas revisarlo con atención.
#
# Además, es importante documentar correctamente cualquier accidente de tráfico para evitar problemas futuros y asegurarte de que se respeten tus derechos legales. Si necesitas ayuda para completar el parte o tienes dudas sobre lo ocurrido, puedes consultar a un profesional o a la policía presente en el lugar.
#
# Recuerda que firmar documentos falsos puede tener consecuencias legales serias.
#
# ================================================================================
#
# 🙋‍♂️ Conductor: Tengo una hemorragia en el brazo tras el choque, ¿qué hago?
# ------------------------------------------------------------
# 🔍 Chunks recuperados matemáticamente: 4
#    - Fuente: Manual-IX-Primeros-Auxilios_2024.pdf (Pág. 68)
#    - Fuente: manual_basico_rescate.pdf (Pág. 69)
#    - Fuente: Manual-IX-Primeros-Auxilios_2024.pdf (Pág. 90)
#    - Fuente: Manual-IX-Primeros-Auxilios_2024.pdf (Pág. 67)
#
# 🤖 SafeDrive AI:
# Para controlar la hemorragia en tu brazo, debes seguir estos pasos:
#
# 1. **Presiona firmemente sobre la arteria humeral**: Localiza la arteria humeral, que se encuentra aproximadamente en la mitad del interior del brazo, bajo el relieve del bíceps. Presiona con fuerza utilizando un paño o apósito si lo tienes a mano.
#
# 2. **Mantén la presión constante**: No te despegues de esa zona hasta que llegue ayuda médica profesional. La presión es crucial para controlar la hemorragia.
#
# 3. **Si el sangrado no se detiene, busca ayuda médica inmediata**: Si después de aplicar la presión durante unos minutos la hemorragia sigue sin detenerse, es importante buscar atención médica lo antes posible.
#
# Recuerda que esta acción es solo un primer paso y que debes intentar mantener la calma para evitar una mayor pérdida de sangre.
#
# ================================================================================
#
# 🙋‍♂️ Conductor: He chocado en una curva donde había una señal triangular blanca con borde rojo. ¿Cómo pongo el vehículo de auxilio?
# ------------------------------------------------------------
# 🔍 Chunks recuperados matemáticamente: 4
#    - Fuente: Protocolo-Auxilio-en-Carretera.pdf (Pág. 21)
#    - Fuente: Protocolo-Auxilio-en-Carretera.pdf (Pág. 15)
#    - Fuente: Protocolo-Auxilio-en-Carretera.pdf (Pág. 26)
#    - Fuente: Protocolo-Auxilio-en-Carretera.pdf (Pág. 13)
#
# 🤖 SafeDrive AI:
# No tengo la información específica sobre cómo colocar un vehículo de auxilio exactamente en esa situación, ya que los detalles específicos dependen del contexto local y pueden variar. Sin embargo, puedo ofrecerte algunas orientaciones generales basadas en el protocolo proporcionado:
#
# 1. **Posición del Vehículo de Auxilio**: Coloca tu vehículo de auxilio al menos 20 metros detrás del vehículo que ha chocado. Asegúrate de que la posición sea lo más paralela posible al flujo de tráfico.
#
# 2. **Giro de las Ruedas**: Gira las ruedas del eje directriz hacia el lado contrario a la corriente de tráfico para maximizar la visibilidad y reducir el riesgo de colisiones laterales.
#
# 3. **Señalización y Balizamiento**: Utiliza toda la señalización de emergencia disponible, incluyendo conos o triángulos de emergencia adicionales si es necesario, especialmente en áreas con baja visibilidad como curvas.
#
# 4. **Cuidado en Curvas**: Ten especial cuidado al colocar el vehículo de auxilio en una curva debido a la reducida visibilidad y los riesgos asociados con vehículos que puedan colisionar desde ambos lados.
#
# 5. **Evaluación Continua de Riesgos**: Asegúrate de evaluar continuamente los riesgos hasta que todas las operaciones hayan terminado, el vehículo afectado haya sido retirado y tu propio vehículo de auxilio esté en un lugar seguro para retomar la circulación.
#
# Si tienes dudas específicas sobre cómo actuar en esta situación, te recomendaría consultar con un profesional o seguir las instrucciones locales más detalladas.
#
# ================================================================================

# %% [markdown]
# ## 🎨 Paso 9: Visualización 2D (PCA Local)
# Proyecta los vectores matemáticos generados por Nomic en un plano 2D para comprobar visualmente si el modelo ha agrupado los documentos por conceptos.

# %%
print("🎨 Extrayendo vectores y generando proyección PCA 2D...")

# 1. Extraemos todo el contenido de la colección para este paso y el siguiente
datos_coleccion = vectorstore.get(include=["embeddings", "metadatas", "documents"])
vectores = np.array(datos_coleccion["embeddings"])

# 2. Extraemos las fuentes para asignar colores
fuentes = [meta.get("source", "Desconocido") for meta in datos_coleccion["metadatas"]]
fuentes_unicas = list(set(fuentes))

# 3. Reducción dimensional PCA (De >700 dimensiones a 2)
pca = PCA(n_components=2)
coords_2d = pca.fit_transform(vectores)

# 4. Renderizado del gráfico
plt.figure(figsize=(12, 8))
colores = plt.cm.get_cmap('tab10', len(fuentes_unicas))

for i, fuente in enumerate(fuentes_unicas):
    idx = [j for j, f in enumerate(fuentes) if f == fuente]
    plt.scatter(
        coords_2d[idx, 0], coords_2d[idx, 1], 
        alpha=0.7, label=fuente, color=colores(i),
        edgecolors='w', linewidth=0.5, s=60
    )

plt.title("Espacio Semántico de SafeDrive AI (PCA)", fontsize=14, pad=15)
plt.xlabel("Componente Principal 1", fontsize=11)
plt.ylabel("Componente Principal 2", fontsize=11)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=9)
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()

plt.show()
# Out:
# 🎨 Extrayendo vectores y generando proyección PCA 2D...
# C:\Users\LittleDragon\AppData\Local\Temp\ipykernel_45628\3331358430.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colores = plt.cm.get_cmap('tab10', len(fuentes_unicas))

# %% [markdown]
# ## 📊 Paso 10: Exportar a TensorFlow Embedding Projector
# Genera los archivos `.tsv` para navegar el espacio tridimensional en la web oficial de TensorFlow.

# %%
print("📦 Exportando base de datos a formato TSV...")

# Exportar embeddings.tsv
with open("embeddings.tsv", "w", newline="", encoding="utf-8") as f_vec:
    writer = csv.writer(f_vec, delimiter="\t")
    writer.writerows(datos_coleccion["embeddings"])

# Exportar metadata.tsv
with open("metadata.tsv", "w", newline="", encoding="utf-8") as f_meta:
    writer = csv.writer(f_meta, delimiter="\t")
    writer.writerow(["Fuente", "Pagina", "Texto_Muestra"]) 
    
    for meta, doc in zip(datos_coleccion["metadatas"], datos_coleccion["documents"]):
        texto_limpio = doc.replace("\n", " ").replace("\t", " ")[:150] + "..."
        writer.writerow([meta.get("source", "Desconocido"), meta.get("pagina", 0), texto_limpio])

print("✅ ¡Archivos 'embeddings.tsv' y 'metadata.tsv' generados con éxito!")
print("👉 Sube ambos archivos a: https://projector.tensorflow.org/")
# Out:
# 📦 Exportando base de datos a formato TSV...
# ✅ ¡Archivos 'embeddings.tsv' y 'metadata.tsv' generados con éxito!
# 👉 Sube ambos archivos a: https://projector.tensorflow.org/
